# %% [markdown]
# # GlaSEE pipeline
#
# Full classification pipeline for Sentinel-2 TOA, Sentinel-2 SR, and Landsat 8/9 images.
#
# ## Requirements:
# 1. Google Earth Engine (GEE) account: used to query imagery and the DEM (if no DEM is provided). Sign up for a free account [here](https://earthengine.google.com/new_signup/).
#
# 2. Google Drive folder: Create a folder where output snow cover statistics will be saved. Enter the name of this folder as the `out_folder` variable below. If you don't create the folder ahead of time, duplicates of the same folder will be created for each output file!

# %% [markdown]
# ## Define image search settings and paths

# %%
import os
import ee
import geemap
import sys

# -----Define Google Drive folder for outputs
# Note: Make sure this folder already exists and is the only folder in your "My Drive" with that name. 
out_folder = 'glacier-snow-cover_exports'

# -----Import pipeline utilities
# Assumes pipeline_utils.py is in the same folder as this notebook
script_path = os.getcwd()
sys.path.append(script_path)
import glasee_pipeline_utils as utils

# -----Define image search settings
# Date and month ranges (inclusive)
date_start = '2014-05-01' #default 2014-05-01 start
date_end = '2025-08-15' #default 2025-08-15 end
month_start = 5 #May = 5
month_end = 10 #Oct = 10
# Minimum fill portion percentage of the AOI (0–100), used to remove images after mosaicking by day. 
min_aoi_coverage = 70
# Whether to mask clouds using the respective cloud mask via the geedim package
mask_clouds = True
# Out:
# /Users/ellynenderlin/micromamba/envs/glasee/lib/python3.11/site-packages/geemap/conversion.py:23: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Authenticate and/or Initialize Google Earth Engine (GEE)
#
# Replace the project ID with your GEE project. Default = `ee-{GEE-username}`

# %%
project_id = "ee-ellynenderlin"

try:
    ee.Initialize(project=project_id)
except:
    ee.Authenticate()
    ee.Initialize(project=project_id)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_7TDKVSyKvBdmMqW?ref=4i2o6

# %% [markdown]
# ## Run the pipeline for a single glacier
#
# ### Select the Area of Interest (AOI) from the Randolph Glacier Inventory (RGI) dataset
#
# This cell will plot the RGI dataset on a map. To find a glacier, click on the wrench in the upper right toolbox of the map, and use the "Inspector" to click on a polygon and view the its properties. Right click on the "rgi_id" property to highlight and then copy. Replace the `rgi_id` variable below with your selected site.

# %%
# Load the RGI v7 dataset
rgi = ee.FeatureCollection("projects/ee-raineyaberle/assets/glacier-snow-cover-mapping/RGI2000-v7-G")

# Select a glacier by the RGI v7 ID
rgi_id = 'RGI2000-v7.0-G-01-05740' #RGI2000-v7.0-G-01-11350 (Wolverine), RGI2000-v7.0-G-01-05299 (Gulkana), RGI2000-v7.0-G-01-05740 (Kennicott), 17516 (Casement)
                                 
# Grab the geometry
aoi = rgi.filter(ee.Filter.eq('rgi_id', rgi_id))
aoi = aoi.geometry()
aoi_area = aoi.area().getInfo() # save area [m^2] for splitting date ranges later
print(f"Glacier area = {int(aoi_area/1e6)} km2")

# Create a Map
Map = geemap.Map()
Map.addLayer(rgi, {'color': 'blue', 'opacity':  0.5}, 'RGI v7')
Map.addLayer(aoi, {'color': 'orange', 'opacity': 0.8}, 'AOI')
Map.centerObject(aoi)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Glacier area = 290 km2
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# ### Load the Digital Elevation Model (DEM)
#
# Default: use the ArcticDEM Mosaic where there is > 90 % coverage. Otherwise, use the NASADEM. For sites that use the ArcticDEM Mosaic, elevations are reprojected to the EGM96 geoid to match the vertical datum of NASADEM.

# %%
# Query GEE for DEM
dem = utils.query_gee_for_dem(aoi)

# Add DEM to map
# grab min and max elevations for color limits
minMax = dem.reduceRegion(reducer=ee.Reducer.minMax(),
                          geometry=aoi, 
                          scale=30,
                          maxPixels=1e9,
                          bestEffort=True)
elev_min = minMax.get('elevation_min')
elev_max = minMax.get('elevation_max')
print(f'Elevation range = {int(elev_min.getInfo())} to {int(elev_max.getInfo())} m')
# colors based on the "terrain" palette from matplotlib
palette = ['#333399', '#0d7fe5', '#00be90','#55dd77','#c6f48e','#e3db8a','#aa926b','#8e6e67','#c6b6b3','#ffffff']
Map.addLayer(dem, {'palette': palette, 'min': elev_min, 'max': elev_max}, 'DEM')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# Elevation range = 408 to 4967 m

# %% [markdown]
# Run Sentinel-2 Top of Atmosphere (2016-present), Sentinel-2 Surface Reflectance (2019-present), and Landsat 8/9 (2013-present): 2016 onwards

# %%
for dataset in ['Sentinel-2_TOA','Sentinel-2_SR','Landsat']: 
    utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# AOI area < 250 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-17516_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 225
# ('2019-06-01', '2019-06-30')
# ...current queue length 226
# ('2019-07-01', '2019-07-31')
# ...current queue length 227
# ('2019-08-01', '2019-08-31')
# ...current queue length 228
# ('2019-09-01', '2019-09-30')
# ...current queue length 229
# ('2019-10-01', '2019-10-31')
# ...current queue length 230
# ('2020-05-01', '2020-05-31')
# ...current queue length 231
# ('2020-06-01', '2020-06-30')
# ...current queue length 231
# ('2020-07-01', '2020-07-31')
# ...current queue length 232
# ('2020-08-01', '2020-08-31')
# ...current queue length 233
# ('2020-09-01', '2020-09-30')
# ...current queue length 234
# ('2020-10-01', '2020-10-31')
# ...current queue length 235
# ('2021-05-01', '2021-05-31')
# ...current queue length 236
# ('2021-06-01', '2021-06-30')
# ...current queue length 236
# ('2021-07-01', '2021-07-31')
# ...current queue length 237
# ('2021-08-01', '2021-08-31')
# ...current queue length 237
# ('2021-09-01', '2021-09-30')
# ...current queue length 238
# ('2021-10-01', '2021-10-31')
# ...current queue length 239
# ('2022-05-01', '2022-05-31')
# ...current queue length 240
# ('2022-06-01', '2022-06-30')
# ...current queue length 240
# ('2022-07-01', '2022-07-31')
# ...current queue length 241
# ('2022-08-01', '2022-08-31')
# ...current queue length 242
# ('2022-09-01', '2022-09-30')
# ...current queue length 243
# ('2022-10-01', '2022-10-31')
# ...current queue length 244
# ('2023-05-01', '2023-05-31')
# ...current queue length 245
# ('2023-06-01', '2023-06-30')
# ...current queue length 246
# ('2023-07-01', '2023-07-31')
# ...current queue length 247
# ('2023-08-01', '2023-08-31')
# ...current queue length 248
# ('2023-09-01', '2023-09-30')
# ...current queue length 249
# ('2023-10-01', '2023-10-31')
# ...current queue length 249
# ('2024-05-01', '2024-05-31')
# ...current queue length 250
# ('2024-06-01', '2024-06-30')
# ...current queue length 251
# ('2024-07-01', '2024-07-31')
# ...current queue length 252
# ('2024-08-01', '2024-08-31')
# ...current queue length 253
# ('2024-09-01', '2024-09-30')
# ...current queue length 254
# ('2024-10-01', '2024-10-31')
# ...current queue length 255
# ('2025-05-01', '2025-05-31')
# ...current queue length 255
# ('2025-06-01', '2025-06-30')
# ...current queue length 256
# ('2025-07-01', '2025-07-31')
# ...current queue length 257
# ('2025-08-01', '2025-08-15')
# ...current queue length 258
# AOI area < 250 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-17516_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 259
# ('2014-06-01', '2014-06-30')
# ...current queue length 260
# ('2014-07-01', '2014-07-31')
# ...current queue length 261
# ('2014-08-01', '2014-08-31')
# ...current queue length 262
# ('2014-09-01', '2014-09-30')
# ...current queue length 262
# ('2014-10-01', '2014-10-31')
# ...current queue length 263
# ('2015-05-01', '2015-05-31')
# ...current queue length 263
# ('2015-06-01', '2015-06-30')
# ...current queue length 264
# ('2015-07-01', '2015-07-31')
# ...current queue length 265
# ('2015-08-01', '2015-08-31')
# ...current queue length 266
# ('2015-09-01', '2015-09-30')
# ...current queue length 267
# ('2015-10-01', '2015-10-31')
# ...current queue length 268
# ('2016-05-01', '2016-05-31')
# ...current queue length 269
# ('2016-06-01', '2016-06-30')
# ...current queue length 270
# ('2016-07-01', '2016-07-31')
# ...current queue length 270
# ('2016-08-01', '2016-08-31')
# ...current queue length 271
# ('2016-09-01', '2016-09-30')
# ...current queue length 272
# ('2016-10-01', '2016-10-31')
# ...current queue length 272
# ('2017-05-01', '2017-05-31')
# ...current queue length 273
# ('2017-06-01', '2017-06-30')
# ...current queue length 274
# ('2017-07-01', '2017-07-31')
# ...current queue length 275
# ('2017-08-01', '2017-08-31')
# ...current queue length 276
# ('2017-09-01', '2017-09-30')
# ...current queue length 277
# ('2017-10-01', '2017-10-31')
# ...current queue length 278
# ('2018-05-01', '2018-05-31')
# ...current queue length 279
# ('2018-06-01', '2018-06-30')
# ...current queue length 280
# ('2018-07-01', '2018-07-31')
# ...current queue length 281
# ('2018-08-01', '2018-08-31')
# ...current queue length 281
# ('2018-09-01', '2018-09-30')
# ...current queue length 283
# ('2018-10-01', '2018-10-31')
# ...current queue length 282
# ('2019-05-01', '2019-05-31')
# ...current queue length 283
# ('2019-06-01', '2019-06-30')
# ...current queue length 284
# ('2019-07-01', '2019-07-31')
# ...current queue length 285
# ('2019-08-01', '2019-08-31')
# ...current queue length 286
# ('2019-09-01', '2019-09-30')
# ...current queue length 287
# ('2019-10-01', '2019-10-31')
# ...current queue length 288
# ('2020-05-01', '2020-05-31')
# ...current queue length 289
# ('2020-06-01', '2020-06-30')
# ...current queue length 290
# ('2020-07-01', '2020-07-31')
# ...current queue length 290
# ('2020-08-01', '2020-08-31')
# ...current queue length 290
# ('2020-09-01', '2020-09-30')
# ...current queue length 291
# ('2020-10-01', '2020-10-31')
# ...current queue length 292
# ('2021-05-01', '2021-05-31')
# ...current queue length 293
# ('2021-06-01', '2021-06-30')
# ...current queue length 294
# ('2021-07-01', '2021-07-31')
# ...current queue length 295
# ('2021-08-01', '2021-08-31')
# ...current queue length 296
# ('2021-09-01', '2021-09-30')
# ...current queue length 297
# ('2021-10-01', '2021-10-31')
# ...current queue length 298
# ('2022-05-01', '2022-05-31')
# ...current queue length 299
# ('2022-06-01', '2022-06-30')
# ...current queue length 298
# ('2022-07-01', '2022-07-31')
# ...current queue length 299
# ('2022-08-01', '2022-08-31')
# ...current queue length 300
# ('2022-09-01', '2022-09-30')
# ...current queue length 301
# ('2022-10-01', '2022-10-31')
# ...current queue length 302
# ('2023-05-01', '2023-05-31')
# ...current queue length 303
# ('2023-06-01', '2023-06-30')
# ...current queue length 304
# ('2023-07-01', '2023-07-31')
# ...current queue length 305
# ('2023-08-01', '2023-08-31')
# ...current queue length 306
# ('2023-09-01', '2023-09-30')
# ...current queue length 307
# ('2023-10-01', '2023-10-31')
# ...current queue length 308
# ('2024-05-01', '2024-05-31')
# ...current queue length 307
# ('2024-06-01', '2024-06-30')
# ...current queue length 308
# ('2024-07-01', '2024-07-31')
# ...current queue length 309
# ('2024-08-01', '2024-08-31')
# ...current queue length 310
# ('2024-09-01', '2024-09-30')
# ...current queue length 311
# ('2024-10-01', '2024-10-31')
# ...current queue length 312
# ('2025-05-01', '2025-05-31')
# ...current queue length 313
# ('2025-06-01', '2025-06-30')
# ...current queue length 314
# ('2025-07-01', '2025-07-31')
# ...current queue length 314
# ('2025-08-01', '2025-08-15')
# ...current queue length 315

# %% [markdown]
# OR RUN EACH PLATFORM INDEPENDENTLY AS NEEDED!

# %% [markdown]
# Run Sentinel-2 Top of Atmosphere (TOA): 2016 onwards

# %%
# redefine the date range to narrow in on ~1 month for testing
date_start = '2014-05-01' #default 2014-05-01 start
date_end = '2025-08-15' #default 2025-08-15 end

# %%
dataset = "Sentinel-2_TOA"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

# %% [markdown]
# Run Sentinel-2 Surface Reflectance (SR): 2019 onwards

# %%
dataset = "Sentinel-2_SR"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# AOI area between 250-500 km2, upscaling imagery to 30 m resolution.
# 200 km2 <= AOI < 500 km2 — splitting date range by 10 days.
# Number of date ranges = 116
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-05740_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-10')
# ...current queue length 249
# ('2019-05-11', '2019-05-20')
# ...current queue length 250
# ('2019-05-21', '2019-05-30')
# ...current queue length 251
# ('2019-05-31', '2019-06-09')
# ...current queue length 252
# ('2019-06-10', '2019-06-19')
# ...current queue length 253
# ('2019-06-20', '2019-06-29')
# ...current queue length 254
# ('2019-06-30', '2019-07-09')
# ...current queue length 255
# ('2019-07-10', '2019-07-19')
# ...current queue length 256
# ('2019-07-20', '2019-07-29')
# ...current queue length 257
# ('2019-07-30', '2019-08-08')
# ...current queue length 258
# ('2019-08-09', '2019-08-18')
# ...current queue length 259
# ('2019-08-19', '2019-08-28')
# ...current queue length 260
# ('2019-08-29', '2019-09-07')
# ...current queue length 261
# ('2019-09-08', '2019-09-17')
# ...current queue length 262
# ('2019-09-18', '2019-09-27')
# ...current queue length 262
# ('2019-09-28', '2019-10-07')
# ...current queue length 262
# ('2019-10-08', '2019-10-17')
# ...current queue length 263
# ('2019-10-18', '2019-10-27')
# ...current queue length 264
# ('2020-05-05', '2020-05-14')
# ...current queue length 265
# ('2020-05-15', '2020-05-24')
# ...current queue length 266
# ('2020-05-25', '2020-06-03')
# ...current queue length 267
# ('2020-06-04', '2020-06-13')
# ...current queue length 268
# ('2020-06-14', '2020-06-23')
# ...current queue length 268
# ('2020-06-24', '2020-07-03')
# ...current queue length 269
# ('2020-07-04', '2020-07-13')
# ...current queue length 270
# ('2020-07-14', '2020-07-23')
# ...current queue length 270
# ('2020-07-24', '2020-08-02')
# ...current queue length 271
# ('2020-08-03', '2020-08-12')
# ...current queue length 272
# ('2020-08-13', '2020-08-22')
# ...current queue length 273
# ('2020-08-23', '2020-09-01')
# ...current queue length 274
# ('2020-09-02', '2020-09-11')
# ...current queue length 275
# ('2020-09-12', '2020-09-21')
# ...current queue length 276
# ('2020-09-22', '2020-10-01')
# ...current queue length 277
# ('2020-10-02', '2020-10-11')
# ...current queue length 278
# ('2020-10-12', '2020-10-21')
# ...current queue length 279
# ('2020-10-22', '2020-10-31')
# ...current queue length 280
# ('2021-05-10', '2021-05-19')
# ...current queue length 281
# ('2021-05-20', '2021-05-29')
# ...current queue length 282
# ('2021-05-30', '2021-06-08')
# ...current queue length 283
# ('2021-06-09', '2021-06-18')
# ...current queue length 284
# ('2021-06-19', '2021-06-28')
# ...current queue length 285
# ('2021-06-29', '2021-07-08')
# ...current queue length 285
# ('2021-07-09', '2021-07-18')
# ...current queue length 286
# ('2021-07-19', '2021-07-28')
# ...current queue length 287
# ('2021-07-29', '2021-08-07')
# ...current queue length 288
# ('2021-08-08', '2021-08-17')
# ...current queue length 289
# ('2021-08-18', '2021-08-27')
# ...current queue length 290
# ('2021-08-28', '2021-09-06')
# ...current queue length 291
# ('2021-09-07', '2021-09-16')
# ...current queue length 292
# ('2021-09-17', '2021-09-26')
# ...current queue length 293
# ('2021-09-27', '2021-10-06')
# ...current queue length 294
# ('2021-10-07', '2021-10-16')
# ...current queue length 295
# ('2021-10-17', '2021-10-26')
# ...current queue length 296
# ('2022-05-05', '2022-05-14')
# ...current queue length 297
# ('2022-05-15', '2022-05-24')
# ...current queue length 298
# ('2022-05-25', '2022-06-03')
# ...current queue length 298
# ('2022-06-04', '2022-06-13')
# ...current queue length 299
# ('2022-06-14', '2022-06-23')
# ...current queue length 300
# ('2022-06-24', '2022-07-03')
# ...current queue length 301
# ('2022-07-04', '2022-07-13')
# ...current queue length 302
# ('2022-07-14', '2022-07-23')
# ...current queue length 303
# ('2022-07-24', '2022-08-02')
# ...current queue length 303
# ('2022-08-03', '2022-08-12')
# ...current queue length 304
# ('2022-08-13', '2022-08-22')
# ...current queue length 305
# ('2022-08-23', '2022-09-01')
# ...current queue length 306
# ('2022-09-02', '2022-09-11')
# ...current queue length 307
# ('2022-09-12', '2022-09-21')
# ...current queue length 308
# ('2022-09-22', '2022-10-01')
# ...current queue length 309
# ('2022-10-02', '2022-10-11')
# ...current queue length 310
# ('2022-10-12', '2022-10-21')
# ...current queue length 310
# ('2022-10-22', '2022-10-31')
# ...current queue length 311
# ('2023-05-10', '2023-05-19')
# ...current queue length 311
# ('2023-05-20', '2023-05-29')
# ...current queue length 312
# ('2023-05-30', '2023-06-08')
# ...current queue length 313
# ('2023-06-09', '2023-06-18')
# ...current queue length 314
# ('2023-06-19', '2023-06-28')
# ...current queue length 313
# ('2023-06-29', '2023-07-08')
# ...current queue length 314
# ('2023-07-09', '2023-07-18')
# ...current queue length 315
# ('2023-07-19', '2023-07-28')
# ...current queue length 316
# ('2023-07-29', '2023-08-07')
# ...current queue length 317
# ('2023-08-08', '2023-08-17')
# ...current queue length 318
# ('2023-08-18', '2023-08-27')
# ...current queue length 318
# ('2023-08-28', '2023-09-06')
# ...current queue length 319
# ('2023-09-07', '2023-09-16')
# ...current queue length 319
# ('2023-09-17', '2023-09-26')
# ...current queue length 320
# ('2023-09-27', '2023-10-06')
# ...current queue length 321
# ('2023-10-07', '2023-10-16')
# ...current queue length 322
# ('2023-10-17', '2023-10-26')
# ...current queue length 323
# ('2024-05-04', '2024-05-13')
# ...current queue length 324
# ('2024-05-14', '2024-05-23')
# ...current queue length 324
# ('2024-05-24', '2024-06-02')
# ...current queue length 325
# ('2024-06-03', '2024-06-12')
# ...current queue length 326
# ('2024-06-13', '2024-06-22')
# ...current queue length 327
# ('2024-06-23', '2024-07-02')
# ...current queue length 328
# ('2024-07-03', '2024-07-12')
# ...current queue length 329
# ('2024-07-13', '2024-07-22')
# ...current queue length 330
# ('2024-07-23', '2024-08-01')
# ...current queue length 331
# ('2024-08-02', '2024-08-11')
# ...current queue length 332
# ('2024-08-12', '2024-08-21')
# ...current queue length 333
# ('2024-08-22', '2024-08-31')
# ...current queue length 334
# ('2024-09-01', '2024-09-10')
# ...current queue length 335
# ('2024-09-11', '2024-09-20')
# ...current queue length 336
# ('2024-09-21', '2024-09-30')
# ...current queue length 337
# ('2024-10-01', '2024-10-10')
# ...current queue length 338
# ('2024-10-11', '2024-10-20')
# ...current queue length 339
# ('2024-10-21', '2024-10-30')
# ...current queue length 340
# ('2025-05-09', '2025-05-18')
# ...current queue length 341
# ('2025-05-19', '2025-05-28')
# ...current queue length 342
# ('2025-05-29', '2025-06-07')
# ...current queue length 342
# ('2025-06-08', '2025-06-17')
# ...current queue length 343
# ('2025-06-18', '2025-06-27')
# ...current queue length 344
# ('2025-06-28', '2025-07-07')
# ...current queue length 345
# ('2025-07-08', '2025-07-17')
# ...current queue length 345
# ('2025-07-18', '2025-07-27')
# ...current queue length 346
# ('2025-07-28', '2025-08-06')
# ...current queue length 347
# ('2025-08-07', '2025-08-15')
# ...current queue length 348

# %% [markdown]
# Run Landsat 8/9 SR: 2013 onwards

# %%
dataset = "Landsat"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

# %% [markdown]
# ## Run the pipeline for multiple glaciers
#
# First, create a list of glacier IDs for analysis.
#
# Below is an example selection of glaciers, where the full RGI v. 7 collection is filtered by RGI O2 region ("o2region") and area ("area_km2"). For the full list of properties available for filtering, see the [RGI v. 7 documentation](https://www.glims.org/rgi_user_guide/products/glacier_product.html#full-list-of-attributes) or run the following command:
#
# `rgi.first().propertyNames().getInfo()`

# %%
# Load the RGI v. 7 dataset
rgi = ee.FeatureCollection("projects/ee-raineyaberle/assets/glacier-snow-cover-mapping/RGI2000-v7-G")

# Filter by region and subregion
rgi_r1r2 = rgi.filter(ee.Filter.eq('o2region', '01-05')) # filter by RGI subregion (e.g., "01-05" = Alaska, St. Elias)

# Filter by glacier area
rgi_area_filt = rgi_r1r2.filter(ee.Filter.gt('area_km2', 8)) # area km2
rgi_area_filt = rgi_area_filt.filter(ee.Filter.lt('area_km2', 10)) # area km2 (pixel scaling applies for >3000km^2 and issues arise at >10000km^2)

# Get the list of RGI IDs
id_list = rgi_area_filt.aggregate_array('rgi_id')
id_list = id_list.getInfo()
# print(id_list[52]) #use this to double-check you are restarting on the right index
print('Number of glaciers selected:', len(id_list))

# %%
# Iterate over RGI IDs
for i in range(0,len(id_list))[5:]: #add [0:1] to test for one
    rgi_id = id_list[i]
    print("Glacier #",i)
    print("Glacier ID used for output file names:", rgi_id)

    # grab glacier area of interest
    aoi = rgi.filter(ee.Filter.eq('rgi_id', rgi_id))
    aoi = aoi.geometry()
    aoi_area = aoi.area().getInfo() # save area [m^2] for splitting date ranges later
    print(f"Glacier area = {aoi_area/1e6} km2")

    # Query GEE for DEM
    dem = utils.query_gee_for_dem(aoi) 

    # Run pipeline for each dataset
    for dataset in ['Sentinel-2_TOA','Sentinel-2_SR','Landsat']: #specify ['Sentinel-2_TOA','Sentinel-2_SR','Landsat'] for all satellites
        utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                          min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

    print('...moving on... \n')
