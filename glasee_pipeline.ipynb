# %% [markdown]
# # GlaSEE pipeline
#
# Full classification pipeline for Sentinel-2 TOA, Sentinel-2 SR, and Landsat 8/9 images.
#
# ## Requirements:
# 1. Google Earth Engine (GEE) account: used to query imagery and the DEM (if no DEM is provided). Sign up for a free account [here](https://earthengine.google.com/new_signup/).
#
# 2. Google Drive folder: Create a folder where output snow cover statistics will be saved. Enter the name of this folder as the `out_folder` variable below. If you don't create the folder ahead of time, duplicates of the same folder will be created for each output file!

# %% [markdown]
# ## Define image search settings and paths

# %%
import os
import ee
import geemap
import sys

# -----Define Google Drive folder for outputs
# Note: Make sure this folder already exists and is the only folder in your "My Drive" with that name. 
out_folder = 'glacier-snow-cover_exports'

# -----Import pipeline utilities
# Assumes pipeline_utils.py is in the same folder as this notebook
script_path = os.getcwd()
sys.path.append(script_path)
import glasee_pipeline_utils as utils

# -----Define image search settings
# Date and month ranges (inclusive)
date_start = '2014-05-01'
date_end = '2025-08-15'
month_start = 5 #May = 5
month_end = 10 #Oct = 10
# Minimum fill portion percentage of the AOI (0–100), used to remove images after mosaicking by day. 
min_aoi_coverage = 70
# Whether to mask clouds using the respective cloud mask via the geedim package
mask_clouds = True
# Out:
# /Users/ellynenderlin/micromamba/envs/glasee/lib/python3.11/site-packages/geemap/conversion.py:23: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Authenticate and/or Initialize Google Earth Engine (GEE)
#
# Replace the project ID with your GEE project. Default = `ee-{GEE-username}`

# %%
project_id = "ee-ellynenderlin"

try:
    ee.Initialize(project=project_id)
except:
    ee.Authenticate()
    ee.Initialize(project=project_id)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Run the pipeline for a single glacier
#
# ### Select the Area of Interest (AOI) from the Randolph Glacier Inventory (RGI) dataset
#
# This cell will plot the RGI dataset on a map. To find a glacier, click on the wrench in the upper right toolbox of the map, and use the "Inspector" to click on a polygon and view the its properties. Right click on the "rgi_id" property to highlight and then copy. Replace the `rgi_id` variable below with your selected site.

# %%
# Load the RGI v7 dataset
rgi = ee.FeatureCollection("projects/ee-raineyaberle/assets/glacier-snow-cover-mapping/RGI2000-v7-G")

# Select a glacier by the RGI v7 ID
rgi_id = 'RGI2000-v7.0-G-01-11350'
                                 
# Grab the geometry
aoi = rgi.filter(ee.Filter.eq('rgi_id', rgi_id))
aoi = aoi.geometry()
aoi_area = aoi.area().getInfo() # save area [m^2] for splitting date ranges later
print(f"Glacier area = {int(aoi_area/1e6)} km2")

# Create a Map
Map = geemap.Map()
Map.addLayer(rgi, {'color': 'blue', 'opacity':  0.5}, 'RGI v7')
Map.addLayer(aoi, {'color': 'orange', 'opacity': 0.8}, 'AOI')
Map.centerObject(aoi)
Map

# %% [markdown]
# ### Load the Digital Elevation Model (DEM)
#
# Default: use the ArcticDEM Mosaic where there is > 90 % coverage. Otherwise, use the NASADEM. For sites that use the ArcticDEM Mosaic, elevations are reprojected to the EGM96 geoid to match the vertical datum of NASADEM.

# %%
# Query GEE for DEM
dem = utils.query_gee_for_dem(aoi)

# Add DEM to map
# grab min and max elevations for color limits
minMax = dem.reduceRegion(reducer=ee.Reducer.minMax(),
                          geometry=aoi, 
                          scale=30,
                          maxPixels=1e9,
                          bestEffort=True)
elev_min = minMax.get('elevation_min')
elev_max = minMax.get('elevation_max')
print(f'Elevation range = {int(elev_min.getInfo())} to {int(elev_max.getInfo())} m')
# colors based on the "terrain" palette from matplotlib
palette = ['#333399', '#0d7fe5', '#00be90','#55dd77','#c6f48e','#e3db8a','#aa926b','#8e6e67','#c6b6b3','#ffffff']
Map.addLayer(dem, {'palette': palette, 'min': elev_min, 'max': elev_max}, 'DEM')

# %% [markdown]
# Run Sentinel-2 Top of Atmosphere (TOA): 2016 onwards

# %%
dataset = "Sentinel-2_TOA"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

# %% [markdown]
# Run Sentinel-2 Surface Reflectance (SR): 2019 onwards

# %%
dataset = "Sentinel-2_SR"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

# %% [markdown]
# Run Landsat 8/9 SR: 2013 onwards

# %%
dataset = "Landsat"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

# %% [markdown]
# ## Run the pipeline for multiple glaciers
#
# First, create a list of glacier IDs for analysis.
#
# Below is an example selection of glaciers, where the full RGI v. 7 collection is filtered by RGI O2 region ("o2region") and area ("area_km2"). For the full list of properties available for filtering, see the [RGI v. 7 documentation](https://www.glims.org/rgi_user_guide/products/glacier_product.html#full-list-of-attributes) or run the following command:
#
# `rgi.first().propertyNames().getInfo()`

# %%
# Load the RGI v. 7 dataset
rgi = ee.FeatureCollection("projects/ee-raineyaberle/assets/glacier-snow-cover-mapping/RGI2000-v7-G")

# Filter by region and subregion
rgi_r1r2 = rgi.filter(ee.Filter.eq('o2region', '01-05')) # filter by RGI subregion (e.g., "01-05" = Alaska, St. Elias)

# Filter by glacier area
rgi_area_filt = rgi_r1r2.filter(ee.Filter.gt('area_km2', 10)) # area > 1 km2
rgi_area_filt = rgi_area_filt.filter(ee.Filter.lt('area_km2', 100)) # area < 3000 km2 (pixel scaling applies for >3000km^2 and issues arise at >10000km^2)

# Get the list of RGI IDs
id_list = rgi_area_filt.aggregate_array('rgi_id')
id_list = id_list.getInfo()
# print(id_list)
print('Number of glaciers selected:', len(id_list))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of glaciers selected: 96

# %%
# Iterate over RGI IDs
for i in range(0,len(id_list))[20:]: #add [0:1] to test for one
    rgi_id = id_list[i]
    print("Glacier #",i)
    print("Glacier ID used for output file names:", rgi_id)

    # grab glacier area of interest
    aoi = rgi.filter(ee.Filter.eq('rgi_id', rgi_id))
    aoi = aoi.geometry()
    aoi_area = aoi.area().getInfo() # save area [m^2] for splitting date ranges later
    print(f"Glacier area = {aoi_area/1e6} km2")

    # Query GEE for DEM
    dem = utils.query_gee_for_dem(aoi) 

    # Run pipeline for each dataset
    for dataset in ['Sentinel-2_TOA','Sentinel-2_SR','Landsat']: #specify ['Sentinel-2_TOA','Sentinel-2_SR','Landsat'] for all satellites
        utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                          min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

    print("...moving on...")
    print(" ") #leave a space between iterations!
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Glacier # 3
# Glacier ID used for output file names: RGI2000-v7.0-G-01-14306
# Glacier area = 11.308956877993397 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14306_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14306_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14306_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 4
# Glacier ID used for output file names: RGI2000-v7.0-G-01-14614
# Glacier area = 12.136077351678264 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14614_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14614_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14614_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 5
# Glacier ID used for output file names: RGI2000-v7.0-G-01-15845
# Glacier area = 11.044596216997782 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15845_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15845_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15845_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 6
# Glacier ID used for output file names: RGI2000-v7.0-G-01-14515
# Glacier area = 11.205557324074851 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14515_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14515_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14515_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 7
# Glacier ID used for output file names: RGI2000-v7.0-G-01-15668
# Glacier area = 11.14057187246065 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15668_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15668_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15668_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 8
# Glacier ID used for output file names: RGI2000-v7.0-G-01-15697
# Glacier area = 10.352250868309193 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 99 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15697_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15697_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15697_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 9
# Glacier ID used for output file names: RGI2000-v7.0-G-01-15771
# Glacier area = 10.235657336712181 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15771_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15771_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15771_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 10
# Glacier ID used for output file names: RGI2000-v7.0-G-01-16735
# Glacier area = 10.365871612466377 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-16735_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-16735_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ...
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15219_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15219_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 19
# Glacier ID used for output file names: RGI2000-v7.0-G-01-12394
# Glacier area = 10.586444566837361 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12394_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12394_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12394_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2014-05-01', '2014-05-31')
# ('2014-06-01', '2014-06-30')
# ('2014-07-01', '2014-07-31')
# ('2014-08-01', '2014-08-31')
# ('2014-09-01', '2014-09-30')
# ('2014-10-01', '2014-10-31')
# ('2015-05-01', '2015-05-31')
# ('2015-06-01', '2015-06-30')
# ('2015-07-01', '2015-07-31')
# ('2015-08-01', '2015-08-31')
# ('2015-09-01', '2015-09-30')
# ('2015-10-01', '2015-10-31')
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ('2018-06-01', '2018-06-30')
# ('2018-07-01', '2018-07-31')
# ('2018-08-01', '2018-08-31')
# ('2018-09-01', '2018-09-30')
# ('2018-10-01', '2018-10-31')
# ('2019-05-01', '2019-05-31')
# ('2019-06-01', '2019-06-30')
# ('2019-07-01', '2019-07-31')
# ('2019-08-01', '2019-08-31')
# ('2019-09-01', '2019-09-30')
# ('2019-10-01', '2019-10-31')
# ('2020-05-01', '2020-05-31')
# ('2020-06-01', '2020-06-30')
# ('2020-07-01', '2020-07-31')
# ('2020-08-01', '2020-08-31')
# ('2020-09-01', '2020-09-30')
# ('2020-10-01', '2020-10-31')
# ('2021-05-01', '2021-05-31')
# ('2021-06-01', '2021-06-30')
# ('2021-07-01', '2021-07-31')
# ('2021-08-01', '2021-08-31')
# ('2021-09-01', '2021-09-30')
# ('2021-10-01', '2021-10-31')
# ('2022-05-01', '2022-05-31')
# ('2022-06-01', '2022-06-30')
# ('2022-07-01', '2022-07-31')
# ('2022-08-01', '2022-08-31')
# ('2022-09-01', '2022-09-30')
# ('2022-10-01', '2022-10-31')
# ('2023-05-01', '2023-05-31')
# ('2023-06-01', '2023-06-30')
# ('2023-07-01', '2023-07-31')
# ('2023-08-01', '2023-08-31')
# ('2023-09-01', '2023-09-30')
# ('2023-10-01', '2023-10-31')
# ('2024-05-01', '2024-05-31')
# ('2024-06-01', '2024-06-30')
# ('2024-07-01', '2024-07-31')
# ('2024-08-01', '2024-08-31')
# ('2024-09-01', '2024-09-30')
# ('2024-10-01', '2024-10-31')
# ('2025-05-01', '2025-05-31')
# ('2025-06-01', '2025-06-30')
# ('2025-07-01', '2025-07-31')
# ('2025-08-01', '2025-08-15')
# ...moving on...
# Glacier # 20
# Glacier ID used for output file names: RGI2000-v7.0-G-01-14203
# Glacier area = 20.7218064690147 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-14203_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
#
# ('2016-05-01', '2016-05-31')
# ('2016-06-01', '2016-06-30')
# ('2016-07-01', '2016-07-31')
# ('2016-08-01', '2016-08-31')
# ('2016-09-01', '2016-09-30')
# ('2016-10-01', '2016-10-31')
# ('2017-05-01', '2017-05-31')
# ('2017-06-01', '2017-06-30')
# ('2017-07-01', '2017-07-31')
# ('2017-08-01', '2017-08-31')
# ('2017-09-01', '2017-09-30')
# ('2017-10-01', '2017-10-31')
# ('2018-05-01', '2018-05-31')
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/ee/data.py:409, in _execute_cloud_call(call, num_retries)
#     408 try:
# --> 409   return call.execute(num_retries=num_retries)
#     410 except googleapiclient.errors.HttpError as e:
#
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-ellynenderlin/table:export?alt=json returned "Too many tasks already in the queue (3000, limit 3000).". Details: "Too many tasks already in the queue (3000, limit 3000).">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[6], line 18
#      16 # Run pipeline for each dataset
#      17 for dataset in ['Sentinel-2_TOA','Sentinel-2_SR','Landsat']: #specify ['Sentinel-2_TOA','Sentinel-2_SR','Landsat'] for all satellites
# ---> 18     utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end,
#      19                                       min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)
#      21 print("...moving on...")
#
# File ~/Research/miscellaneous/glasee/glasee_pipeline_utils.py:650, in run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, min_aoi_coverage, mask_clouds, out_folder, glac_id, scale, verbose)
#     647 classified_collection = classify_image_collection(image_collection, dataset, verbose=verbose)
#     649 # Calculate snow cover statistics, export to Google Drive
# --> 650 _ = calculate_snow_cover_statistics(classified_collection, dem, aoi, dataset, scale, out_folder,
#     651                                     file_name_prefix=f"{glac_id}_{dataset}_snow_cover_stats_{date_range[0]}_{date_range[1]}",
#     652                                     verbose=verbose)
#
# File ~/Research/miscellaneous/glasee/glasee_pipeline_utils.py:555, in calculate_snow_cover_statistics(image_collection, dem, aoi, dataset, scale, out_folder, file_name_prefix, verbose)
#     553     time.sleep(30) # wait 30 seconds
#     554     queue = check_queue() # keep checking
# --> 555 task.start()
#     557 if verbose:
#     558     print(f'Exporting snow cover statistics to {out_folder} Google Drive folder with file name: {file_name_prefix}')
#
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/ee/batch.py:150, in Task.start(self)
#     148   result = data.exportMap(self._request_id, self.config)
#     149 elif self.task_type == Task.Type.EXPORT_TABLE:
# --> 150   result = data.exportTable(self._request_id, self.config)
#     151 elif self.task_type == Task.Type.EXPORT_VIDEO:
#     152   result = data.exportVideo(self._request_id, self.config)
#
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/ee/data.py:1795, in exportTable(request_id, params)
#    1774 """Starts a table export task running.
#    1775
#    1776 This is a low-level method. The higher-level ee.batch.Export.table object
#    (...)   1792   If you are using the cloud API, this will be an Operation.
#    1793 """
#    1794 params = params.copy()
# -> 1795 return _prepare_and_run_export(
#    1796     request_id, params, _get_cloud_projects().table().export
#    1797 )
#
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/ee/data.py:1912, in _prepare_and_run_export(request_id, params, export_endpoint)
#    1909   params['expression'] = serializer.encode(
#    1910       params['expression'], for_cloud_api=True)
#    1911 num_retries = _max_retries if request_id else 0
# -> 1912 return _execute_cloud_call(
#    1913     export_endpoint(project=_get_projects_path(), body=params),
#    1914     num_retries=num_retries)
#
# File ~/micromamba/envs/glasee/lib/python3.11/site-packages/ee/data.py:411, in _execute_cloud_call(call, num_retries)
#     409   return call.execute(num_retries=num_retries)
#     410 except googleapiclient.errors.HttpError as e:
# --> 411   raise _translate_cloud_exception(e)
#
# EEException: Too many tasks already in the queue (3000, limit 3000).
