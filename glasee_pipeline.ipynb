# %% [markdown]
# # GlaSEE pipeline
#
# Full classification pipeline for Sentinel-2 TOA, Sentinel-2 SR, and Landsat 8/9 images.
#
# ## Requirements:
# 1. Google Earth Engine (GEE) account: used to query imagery and the DEM (if no DEM is provided). Sign up for a free account [here](https://earthengine.google.com/new_signup/).
#
# 2. Google Drive folder: Create a folder where output snow cover statistics will be saved. Enter the name of this folder as the `out_folder` variable below. If you don't create the folder ahead of time, duplicates of the same folder will be created for each output file!

# %% [markdown]
# ## Define image search settings and paths

# %%
import os
import ee
import geemap
import sys

# -----Define Google Drive folder for outputs
# Note: Make sure this folder already exists and is the only folder in your "My Drive" with that name. 
out_folder = 'glacier-snow-cover_exports'

# -----Import pipeline utilities
# Assumes pipeline_utils.py is in the same folder as this notebook
script_path = os.getcwd()
sys.path.append(script_path)
import glasee_pipeline_utils as utils

# -----Define image search settings
# Date and month ranges (inclusive)
date_start = '2014-05-01' #default 2014-05-01 start
date_end = '2025-08-15' #default 2025-08-15 end
month_start = 5 #May = 5
month_end = 10 #Oct = 10
# Minimum fill portion percentage of the AOI (0–100), used to remove images after mosaicking by day. 
min_aoi_coverage = 70
# Whether to mask clouds using the respective cloud mask via the geedim package
mask_clouds = True
# Out:
# /Users/ellynenderlin/micromamba/envs/glasee/lib/python3.11/site-packages/geemap/conversion.py:23: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Authenticate and/or Initialize Google Earth Engine (GEE)
#
# Replace the project ID with your GEE project. Default = `ee-{GEE-username}`

# %%
project_id = "ee-ellynenderlin"

try:
    ee.Initialize(project=project_id)
except:
    ee.Authenticate()
    ee.Initialize(project=project_id)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Run the pipeline for a single glacier
#
# ### Select the Area of Interest (AOI) from the Randolph Glacier Inventory (RGI) dataset
#
# This cell will plot the RGI dataset on a map. To find a glacier, click on the wrench in the upper right toolbox of the map, and use the "Inspector" to click on a polygon and view the its properties. Right click on the "rgi_id" property to highlight and then copy. Replace the `rgi_id` variable below with your selected site.

# %%
# Load the RGI v7 dataset
rgi = ee.FeatureCollection("projects/ee-raineyaberle/assets/glacier-snow-cover-mapping/RGI2000-v7-G")

# Select a glacier by the RGI v7 ID
rgi_id = 'RGI2000-v7.0-G-01-05740' #RGI2000-v7.0-G-01-11350 (Wolverine), RGI2000-v7.0-G-01-05299 (Gulkana), and RGI2000-v7.0-G-01-05740 (Kennicott)
#check that the RGI outlines are being filtered correctly b/c Kennicott(05470) is clearly not right & has an area of zero
                                 
# Grab the geometry
aoi = rgi.filter(ee.Filter.eq('rgi_id', rgi_id))
aoi = aoi.geometry()
aoi_area = aoi.area().getInfo() # save area [m^2] for splitting date ranges later
print(f"Glacier area = {int(aoi_area/1e6)} km2")

# Create a Map
Map = geemap.Map()
Map.addLayer(rgi, {'color': 'blue', 'opacity':  0.5}, 'RGI v7')
Map.addLayer(aoi, {'color': 'orange', 'opacity': 0.8}, 'AOI')
Map.centerObject(aoi)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Glacier area = 290 km2
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# ### Load the Digital Elevation Model (DEM)
#
# Default: use the ArcticDEM Mosaic where there is > 90 % coverage. Otherwise, use the NASADEM. For sites that use the ArcticDEM Mosaic, elevations are reprojected to the EGM96 geoid to match the vertical datum of NASADEM.

# %%
# Query GEE for DEM
dem = utils.query_gee_for_dem(aoi)

# Add DEM to map
# grab min and max elevations for color limits
minMax = dem.reduceRegion(reducer=ee.Reducer.minMax(),
                          geometry=aoi, 
                          scale=30,
                          maxPixels=1e9,
                          bestEffort=True)
elev_min = minMax.get('elevation_min')
elev_max = minMax.get('elevation_max')
print(f'Elevation range = {int(elev_min.getInfo())} to {int(elev_max.getInfo())} m')
# colors based on the "terrain" palette from matplotlib
palette = ['#333399', '#0d7fe5', '#00be90','#55dd77','#c6f48e','#e3db8a','#aa926b','#8e6e67','#c6b6b3','#ffffff']
Map.addLayer(dem, {'palette': palette, 'min': elev_min, 'max': elev_max}, 'DEM')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# Elevation range = 408 to 4967 m

# %% [markdown]
# Run Sentinel-2 Top of Atmosphere (TOA): 2016 onwards

# %%
dataset = "Sentinel-2_TOA"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-05740_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 727
# ('2016-06-01', '2016-06-30')
# ...current queue length 727
# ('2016-07-01', '2016-07-31')
# ...current queue length 728
# ('2016-08-01', '2016-08-31')
# ...current queue length 728
# ('2016-09-01', '2016-09-30')
# ...current queue length 729
# ('2016-10-01', '2016-10-31')
# ...current queue length 729
# ('2017-05-01', '2017-05-31')
# ...current queue length 730
# ('2017-06-01', '2017-06-30')
# ...current queue length 730
# ('2017-07-01', '2017-07-31')
# ...current queue length 731
# ('2017-08-01', '2017-08-31')
# ...current queue length 725
# ('2017-09-01', '2017-09-30')
# ...current queue length 725
# ('2017-10-01', '2017-10-31')
# ...current queue length 725
# ('2018-05-01', '2018-05-31')
# ...current queue length 726
# ('2018-06-01', '2018-06-30')
# ...current queue length 727
# ('2018-07-01', '2018-07-31')
# ...current queue length 728
# ('2018-08-01', '2018-08-31')
# ...current queue length 727
# ('2018-09-01', '2018-09-30')
# ...current queue length 728
# ('2018-10-01', '2018-10-31')
# ...current queue length 729
# ('2019-05-01', '2019-05-31')
# ...current queue length 730
# ('2019-06-01', '2019-06-30')
# ...current queue length 731
# ('2019-07-01', '2019-07-31')
# ...current queue length 731
# ('2019-08-01', '2019-08-31')
# ...current queue length 732
# ('2019-09-01', '2019-09-30')
# ...current queue length 731
# ('2019-10-01', '2019-10-31')
# ...current queue length 732
# ('2020-05-01', '2020-05-31')
# ...current queue length 733
# ('2020-06-01', '2020-06-30')
# ...current queue length 733
# ('2020-07-01', '2020-07-31')
# ...current queue length 734
# ('2020-08-01', '2020-08-31')
# ...current queue length 735
# ('2020-09-01', '2020-09-30')
# ...current queue length 736
# ('2020-10-01', '2020-10-31')
# ...current queue length 736
# ('2021-05-01', '2021-05-31')
# ...current queue length 738
# ('2021-06-01', '2021-06-30')
# ...current queue length 737
# ('2021-07-01', '2021-07-31')
# ...current queue length 738
# ('2021-08-01', '2021-08-31')
# ...current queue length 739
# ('2021-09-01', '2021-09-30')
# ...current queue length 740
# ('2021-10-01', '2021-10-31')
# ...current queue length 740
# ('2022-05-01', '2022-05-31')
# ...current queue length 741
# ('2022-06-01', '2022-06-30')
# ...current queue length 741
# ('2022-07-01', '2022-07-31')
# ...current queue length 742
# ('2022-08-01', '2022-08-31')
# ...current queue length 742
# ('2022-09-01', '2022-09-30')
# ...current queue length 743
# ('2022-10-01', '2022-10-31')
# ...current queue length 743
# ('2023-05-01', '2023-05-31')
# ...current queue length 744
# ('2023-06-01', '2023-06-30')
# ...current queue length 745
# ('2023-07-01', '2023-07-31')
# ...current queue length 746
# ('2023-08-01', '2023-08-31')
# ...current queue length 747
# ('2023-09-01', '2023-09-30')
# ...current queue length 748
# ('2023-10-01', '2023-10-31')
# ...current queue length 747
# ('2024-05-01', '2024-05-31')
# ...current queue length 748
# ('2024-06-01', '2024-06-30')
# ...current queue length 749
# ('2024-07-01', '2024-07-31')
# ...current queue length 750
# ('2024-08-01', '2024-08-31')
# ...current queue length 750
# ('2024-09-01', '2024-09-30')
# ...current queue length 751
# ('2024-10-01', '2024-10-31')
# ...current queue length 752
# ('2025-05-01', '2025-05-31')
# ...current queue length 750
# ('2025-06-01', '2025-06-30')
# ...current queue length 751
# ('2025-07-01', '2025-07-31')
# ...current queue length 751
# ('2025-08-01', '2025-08-15')
# ...current queue length 751
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-05740_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 752
# ('2019-06-01', '2019-06-30')
# ...current queue length 751
# ('2019-07-01', '2019-07-31')
# ...current queue length 751
# ('2019-08-01', '2019-08-31')
# ...current queue length 752
# ('2019-09-01', '2019-09-30')
# ...current queue length 753
# ('2019-10-01', '2019-10-31')
# ...current queue length 754
# ('2020-05-01', '2020-05-31')
# ...current queue length 755
# ('2020-06-01', '2020-06-30')
# ...current queue length 756
# ('2020-07-01', '2020-07-31')
# ...current queue length 755
# ('2020-08-01', '2020-08-31')
# ...current queue length 756
# ('2020-09-01', '2020-09-30')
# ...current queue length 757
# ('2020-10-01', '2020-10-31')
# ...current queue length 758
# ('2021-05-01', '2021-05-31')
# ...current queue length 757
# ('2021-06-01', '2021-06-30')
# ...current queue length 758
# ('2021-07-01', '2021-07-31')
# ...current queue length 758
# ('2021-08-01', '2021-08-31')
# ...current queue length 759
# ('2021-09-01', '2021-09-30')
# ...current queue length 760
# ('2021-10-01', '2021-10-31')
# ...current queue length 760
# ('2022-05-01', '2022-05-31')
# ...current queue length 761
# ('2022-06-01', '2022-06-30')
# ...current queue length 762
# ('2022-07-01', '2022-07-31')
# ...current queue length 763
# ('2022-08-01', '2022-08-31')
# ...current queue length 764
# ('2022-09-01', '2022-09-30')
# ...current queue length 764
# ('2022-10-01', '2022-10-31')
# ...current queue length 765
# ('2023-05-01', '2023-05-31')
# ...current queue length 766
# ('2023-06-01', '2023-06-30')
# ...current queue length 766
# ('2023-07-01', '2023-07-31')
# ...current queue length 767
# ('2023-08-01', '2023-08-31')
# ...current queue length 768
# ('2023-09-01', '2023-09-30')
# ...current queue length 769
# ('2023-10-01', '2023-10-31')
# ...current queue length 770
# ('2024-05-01', '2024-05-31')
# ...current queue length 770
# ('2024-06-01', '2024-06-30')
# ...current queue length 771
# ('2024-07-01', '2024-07-31')
# ...current queue length 772
# ('2024-08-01', '2024-08-31')
# ...current queue length 773
# ('2024-09-01', '2024-09-30')
# ...current queue length 774
# ('2024-10-01', '2024-10-31')
# ...current queue length 774
# ('2025-05-01', '2025-05-31')
# ...current queue length 774
# ('2025-06-01', '2025-06-30')
# ...current queue length 775
# ('2025-07-01', '2025-07-31')
# ...current queue length 776
# ('2025-08-01', '2025-08-15')
# ...current queue length 775

# %% [markdown]
# Run Sentinel-2 Surface Reflectance (SR): 2019 onwards

# %%
dataset = "Sentinel-2_SR"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-11350_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 701
# ('2019-06-01', '2019-06-30')
# ...current queue length 702
# ('2019-07-01', '2019-07-31')
# ...current queue length 703
# ('2019-08-01', '2019-08-31')
# ...current queue length 704
# ('2019-09-01', '2019-09-30')
# ...current queue length 705
# ('2019-10-01', '2019-10-31')
# ...current queue length 706
# ('2020-05-01', '2020-05-31')
# ...current queue length 707
# ('2020-06-01', '2020-06-30')
# ...current queue length 708
# ('2020-07-01', '2020-07-31')
# ...current queue length 709
# ('2020-08-01', '2020-08-31')
# ...current queue length 710
# ('2020-09-01', '2020-09-30')
# ...current queue length 710
# ('2020-10-01', '2020-10-31')
# ...current queue length 711
# ('2021-05-01', '2021-05-31')
# ...current queue length 712
# ('2021-06-01', '2021-06-30')
# ...current queue length 713
# ('2021-07-01', '2021-07-31')
# ...current queue length 714
# ('2021-08-01', '2021-08-31')
# ...current queue length 715
# ('2021-09-01', '2021-09-30')
# ...current queue length 716
# ('2021-10-01', '2021-10-31')
# ...current queue length 717
# ('2022-05-01', '2022-05-31')
# ...current queue length 718
# ('2022-06-01', '2022-06-30')
# ...current queue length 719
# ('2022-07-01', '2022-07-31')
# ...current queue length 720
# ('2022-08-01', '2022-08-31')
# ...current queue length 721
# ('2022-09-01', '2022-09-30')
# ...current queue length 722
# ('2022-10-01', '2022-10-31')
# ...current queue length 723
# ('2023-05-01', '2023-05-31')
# ...current queue length 724
# ('2023-06-01', '2023-06-30')
# ...current queue length 725
# ('2023-07-01', '2023-07-31')
# ...current queue length 726
# ('2023-08-01', '2023-08-31')
# ...current queue length 727
# ('2023-09-01', '2023-09-30')
# ...current queue length 728
# ('2023-10-01', '2023-10-31')
# ...current queue length 729
# ('2024-05-01', '2024-05-31')
# ...current queue length 729
# ('2024-06-01', '2024-06-30')
# ...current queue length 730
# ('2024-07-01', '2024-07-31')
# ...current queue length 731
# ('2024-08-01', '2024-08-31')
# ...current queue length 732
# ('2024-09-01', '2024-09-30')
# ...current queue length 733
# ('2024-10-01', '2024-10-31')
# ...current queue length 734
# ('2025-05-01', '2025-05-31')
# ...current queue length 735
# ('2025-06-01', '2025-06-30')
# ...current queue length 736
# ('2025-07-01', '2025-07-31')
# ...current queue length 737
# ('2025-08-01', '2025-08-15')
# ...current queue length 737

# %% [markdown]
# Run Landsat 8/9 SR: 2013 onwards

# %%
dataset = "Landsat"
utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                  min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-11350_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 736
# ('2014-06-01', '2014-06-30')
# ...current queue length 737
# ('2014-07-01', '2014-07-31')
# ...current queue length 738
# ('2014-08-01', '2014-08-31')
# ...current queue length 739
# ('2014-09-01', '2014-09-30')
# ...current queue length 740
# ('2014-10-01', '2014-10-31')
# ...current queue length 741
# ('2015-05-01', '2015-05-31')
# ...current queue length 742
# ('2015-06-01', '2015-06-30')
# ...current queue length 743
# ('2015-07-01', '2015-07-31')
# ...current queue length 744
# ('2015-08-01', '2015-08-31')
# ...current queue length 745
# ('2015-09-01', '2015-09-30')
# ...current queue length 745
# ('2015-10-01', '2015-10-31')
# ...current queue length 746
# ('2016-05-01', '2016-05-31')
# ...current queue length 746
# ('2016-06-01', '2016-06-30')
# ...current queue length 747
# ('2016-07-01', '2016-07-31')
# ...current queue length 748
# ('2016-08-01', '2016-08-31')
# ...current queue length 748
# ('2016-09-01', '2016-09-30')
# ...current queue length 749
# ('2016-10-01', '2016-10-31')
# ...current queue length 750
# ('2017-05-01', '2017-05-31')
# ...current queue length 751
# ('2017-06-01', '2017-06-30')
# ...current queue length 752
# ('2017-07-01', '2017-07-31')
# ...current queue length 753
# ('2017-08-01', '2017-08-31')
# ...current queue length 754
# ('2017-09-01', '2017-09-30')
# ...current queue length 755
# ('2017-10-01', '2017-10-31')
# ...current queue length 756
# ('2018-05-01', '2018-05-31')
# ...current queue length 757
# ('2018-06-01', '2018-06-30')
# ...current queue length 758
# ('2018-07-01', '2018-07-31')
# ...current queue length 759
# ('2018-08-01', '2018-08-31')
# ...current queue length 760
# ('2018-09-01', '2018-09-30')
# ...current queue length 761
# ('2018-10-01', '2018-10-31')
# ...current queue length 762
# ('2019-05-01', '2019-05-31')
# ...current queue length 763
# ('2019-06-01', '2019-06-30')
# ...current queue length 764
# ('2019-07-01', '2019-07-31')
# ...current queue length 765
# ('2019-08-01', '2019-08-31')
# ...current queue length 765
# ('2019-09-01', '2019-09-30')
# ...current queue length 767
# ('2019-10-01', '2019-10-31')
# ...current queue length 767
# ('2020-05-01', '2020-05-31')
# ...current queue length 768
# ('2020-06-01', '2020-06-30')
# ...current queue length 769
# ('2020-07-01', '2020-07-31')
# ...current queue length 770
# ('2020-08-01', '2020-08-31')
# ...current queue length 771
# ('2020-09-01', '2020-09-30')
# ...current queue length 772
# ('2020-10-01', '2020-10-31')
# ...current queue length 773
# ('2021-05-01', '2021-05-31')
# ...current queue length 773
# ('2021-06-01', '2021-06-30')
# ...current queue length 774
# ('2021-07-01', '2021-07-31')
# ...current queue length 775
# ('2021-08-01', '2021-08-31')
# ...current queue length 776
# ('2021-09-01', '2021-09-30')
# ...current queue length 777
# ('2021-10-01', '2021-10-31')
# ...current queue length 778
# ('2022-05-01', '2022-05-31')
# ...current queue length 779
# ('2022-06-01', '2022-06-30')
# ...current queue length 780
# ('2022-07-01', '2022-07-31')
# ...current queue length 781
# ('2022-08-01', '2022-08-31')
# ...current queue length 782
# ('2022-09-01', '2022-09-30')
# ...current queue length 783
# ('2022-10-01', '2022-10-31')
# ...current queue length 784
# ('2023-05-01', '2023-05-31')
# ...current queue length 785
# ('2023-06-01', '2023-06-30')
# ...current queue length 786
# ('2023-07-01', '2023-07-31')
# ...current queue length 787
# ('2023-08-01', '2023-08-31')
# ...current queue length 787
# ('2023-09-01', '2023-09-30')
# ...current queue length 788
# ('2023-10-01', '2023-10-31')
# ...current queue length 789
# ('2024-05-01', '2024-05-31')
# ...current queue length 790
# ('2024-06-01', '2024-06-30')
# ...current queue length 791
# ('2024-07-01', '2024-07-31')
# ...current queue length 792
# ('2024-08-01', '2024-08-31')
# ...current queue length 793
# ('2024-09-01', '2024-09-30')
# ...current queue length 794
# ('2024-10-01', '2024-10-31')
# ...current queue length 795
# ('2025-05-01', '2025-05-31')
# ...current queue length 795
# ('2025-06-01', '2025-06-30')
# ...current queue length 796
# ('2025-07-01', '2025-07-31')
# ...current queue length 797
# ('2025-08-01', '2025-08-15')
# ...current queue length 798

# %% [markdown]
# ## Run the pipeline for multiple glaciers
#
# First, create a list of glacier IDs for analysis.
#
# Below is an example selection of glaciers, where the full RGI v. 7 collection is filtered by RGI O2 region ("o2region") and area ("area_km2"). For the full list of properties available for filtering, see the [RGI v. 7 documentation](https://www.glims.org/rgi_user_guide/products/glacier_product.html#full-list-of-attributes) or run the following command:
#
# `rgi.first().propertyNames().getInfo()`

# %%
# Load the RGI v. 7 dataset
rgi = ee.FeatureCollection("projects/ee-raineyaberle/assets/glacier-snow-cover-mapping/RGI2000-v7-G")

# Filter by region and subregion
rgi_r1r2 = rgi.filter(ee.Filter.eq('o2region', '01-05')) # filter by RGI subregion (e.g., "01-05" = Alaska, St. Elias)

# Filter by glacier area
rgi_area_filt = rgi_r1r2.filter(ee.Filter.gt('area_km2', 10)) # area km2
rgi_area_filt = rgi_area_filt.filter(ee.Filter.lt('area_km2', 100)) # area km2 (pixel scaling applies for >3000km^2 and issues arise at >10000km^2)

# Get the list of RGI IDs
id_list = rgi_area_filt.aggregate_array('rgi_id')
id_list = id_list.getInfo()
# print(id_list[52]) #use this to double-check you are restarting on the right index
print('Number of glaciers selected:', len(id_list))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of glaciers selected: 96

# %%
# Iterate over RGI IDs
for i in range(0,len(id_list))[55:]: #add [0:1] to test for one
    rgi_id = id_list[i]
    print("Glacier #",i)
    print("Glacier ID used for output file names:", rgi_id)

    # grab glacier area of interest
    aoi = rgi.filter(ee.Filter.eq('rgi_id', rgi_id))
    aoi = aoi.geometry()
    aoi_area = aoi.area().getInfo() # save area [m^2] for splitting date ranges later
    print(f"Glacier area = {aoi_area/1e6} km2")

    # Query GEE for DEM
    dem = utils.query_gee_for_dem(aoi) 

    # Run pipeline for each dataset
    for dataset in ['Sentinel-2_TOA','Sentinel-2_SR','Landsat']: #specify ['Sentinel-2_TOA','Sentinel-2_SR','Landsat'] for all satellites
        utils.run_classification_pipeline(aoi, aoi_area, dem, dataset, date_start, date_end, month_start, month_end, 
                                          min_aoi_coverage, mask_clouds, out_folder, rgi_id, scale=None, verbose=False)

    print('...moving on... \n')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Glacier # 55
# Glacier ID used for output file names: RGI2000-v7.0-G-01-15851
# Glacier area = 16.392540674208696 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 99 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15851_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 745
# ('2016-06-01', '2016-06-30')
# ...current queue length 746
# ('2016-07-01', '2016-07-31')
# ...current queue length 747
# ('2016-08-01', '2016-08-31')
# ...current queue length 748
# ('2016-09-01', '2016-09-30')
# ...current queue length 749
# ('2016-10-01', '2016-10-31')
# ...current queue length 750
# ('2017-05-01', '2017-05-31')
# ...current queue length 751
# ('2017-06-01', '2017-06-30')
# ...current queue length 752
# ('2017-07-01', '2017-07-31')
# ...current queue length 753
# ('2017-08-01', '2017-08-31')
# ...current queue length 754
# ('2017-09-01', '2017-09-30')
# ...current queue length 754
# ('2017-10-01', '2017-10-31')
# ...current queue length 755
# ('2018-05-01', '2018-05-31')
# ...current queue length 756
# ('2018-06-01', '2018-06-30')
# ...current queue length 757
# ('2018-07-01', '2018-07-31')
# ...current queue length 758
# ('2018-08-01', '2018-08-31')
# ...current queue length 759
# ('2018-09-01', '2018-09-30')
# ...current queue length 760
# ('2018-10-01', '2018-10-31')
# ...current queue length 761
# ('2019-05-01', '2019-05-31')
# ...current queue length 762
# ('2019-06-01', '2019-06-30')
# ...current queue length 763
# ('2019-07-01', '2019-07-31')
# ...current queue length 764
# ('2019-08-01', '2019-08-31')
# ...current queue length 765
# ('2019-09-01', '2019-09-30')
# ...current queue length 765
# ('2019-10-01', '2019-10-31')
# ...current queue length 765
# ('2020-05-01', '2020-05-31')
# ...current queue length 766
# ('2020-06-01', '2020-06-30')
# ...current queue length 767
# ('2020-07-01', '2020-07-31')
# ...current queue length 768
# ('2020-08-01', '2020-08-31')
# ...current queue length 769
# ('2020-09-01', '2020-09-30')
# ...current queue length 770
# ('2020-10-01', '2020-10-31')
# ...current queue length 771
# ('2021-05-01', '2021-05-31')
# ...current queue length 772
# ('2021-06-01', '2021-06-30')
# ...current queue length 773
# ('2021-07-01', '2021-07-31')
# ...current queue length 774
# ('2021-08-01', '2021-08-31')
# ...current queue length 775
# ('2021-09-01', '2021-09-30')
# ...current queue length 776
# ('2021-10-01', '2021-10-31')
# ...current queue length 777
# ('2022-05-01', '2022-05-31')
# ...current queue length 778
# ('2022-06-01', '2022-06-30')
# ...current queue length 779
# ('2022-07-01', '2022-07-31')
# ...current queue length 780
# ('2022-08-01', '2022-08-31')
# ...current queue length 781
# ('2022-09-01', '2022-09-30')
# ...current queue length 782
# ('2022-10-01', '2022-10-31')
# ...current queue length 783
# ('2023-05-01', '2023-05-31')
# ...current queue length 784
# ('2023-06-01', '2023-06-30')
# ...current queue length 785
# ('2023-07-01', '2023-07-31')
# ...current queue length 786
# ('2023-08-01', '2023-08-31')
# ...current queue length 787
# ('2023-09-01', '2023-09-30')
# ...current queue length 788
# ('2023-10-01', '2023-10-31')
# ...current queue length 789
# ('2024-05-01', '2024-05-31')
# ...current queue length 790
# ('2024-06-01', '2024-06-30')
# ...current queue length 791
# ('2024-07-01', '2024-07-31')
# ...current queue length 792
# ('2024-08-01', '2024-08-31')
# ...current queue length 793
# ('2024-09-01', '2024-09-30')
# ...current queue length 794
# ('2024-10-01', '2024-10-31')
# ...current queue length 795
# ('2025-05-01', '2025-05-31')
# ...current queue length 796
# ('2025-06-01', '2025-06-30')
# ...current queue length 797
# ('2025-07-01', '2025-07-31')
# ...current queue length 798
# ('2025-08-01', '2025-08-15')
# ...current queue length 799
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15851_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 800
# ('2019-06-01', '2019-06-30')
# ...current queue length 801
# ('2019-07-01', '2019-07-31')
# ...current queue length 802
# ('2019-08-01', '2019-08-31')
# ...current queue length 803
# ('2019-09-01', '2019-09-30')
# ...current queue length 804
# ('2019-10-01', '2019-10-31')
# ...current queue length 805
# ('2020-05-01', '2020-05-31')
# ...current queue length 806
# ('2020-06-01', '2020-06-30')
# ...current queue length 806
# ('2020-07-01', '2020-07-31')
# ...current queue length 807
# ('2020-08-01', '2020-08-31')
# ...current queue length 808
# ('2020-09-01', '2020-09-30')
# ...current queue length 809
# ('2020-10-01', '2020-10-31')
# ...current queue length 810
# ('2021-05-01', '2021-05-31')
# ...current queue length 811
# ('2021-06-01', '2021-06-30')
# ...current queue length 812
# ('2021-07-01', '2021-07-31')
# ...current queue length 813
# ('2021-08-01', '2021-08-31')
# ...current queue length 814
# ('2021-09-01', '2021-09-30')
# ...current queue length 815
# ('2021-10-01', '2021-10-31')
# ...current queue length 816
# ('2022-05-01', '2022-05-31')
# ...current queue length 817
# ('2022-06-01', '2022-06-30')
# ...current queue length 818
# ('2022-07-01', '2022-07-31')
# ...current queue length 819
# ('2022-08-01', '2022-08-31')
# ...current queue length 820
# ('2022-09-01', '2022-09-30')
# ...current queue length 821
# ('2022-10-01', '2022-10-31')
# ...current queue length 822
# ('2023-05-01', '2023-05-31')
# ...current queue length 823
# ('2023-06-01', '2023-06-30')
# ...current queue length 824
# ('2023-07-01', '2023-07-31')
# ...current queue length 825
# ('2023-08-01', '2023-08-31')
# ...current queue length 826
# ('2023-09-01', '2023-09-30')
# ...current queue length 827
# ('2023-10-01', '2023-10-31')
# ...current queue length 828
# ('2024-05-01', '2024-05-31')
# ...current queue length 829
# ('2024-06-01', '2024-06-30')
# ...current queue length 830
# ('2024-07-01', '2024-07-31')
# ...current queue length 831
# ('2024-08-01', '2024-08-31')
# ...current queue length 832
# ('2024-09-01', '2024-09-30')
# ...current queue length 833
# ('2024-10-01', '2024-10-31')
# ...current queue length 833
# ('2025-05-01', '2025-05-31')
# ...current queue length 834
# ('2025-06-01', '2025-06-30')
# ...current queue length 835
# ('2025-07-01', '2025-07-31')
# ...current queue length 836
# ('2025-08-01', '2025-08-15')
# ...current queue length 837
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15851_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 838
# ('2014-06-01', '2014-06-30')
# ...current queue length 839
# ('2014-07-01', '2014-07-31')
# ...current queue length 840
# ('2014-08-01', '2014-08-31')
# ...current queue length 841
# ('2014-09-01', '2014-09-30')
# ...current queue length 842
# ('2014-10-01', '2014-10-31')
# ...current queue length 843
# ('2015-05-01', '2015-05-31')
# ...current queue length 844
# ('2015-06-01', '2015-06-30')
# ...current queue length 845
# ('2015-07-01', '2015-07-31')
# ...current queue length 846
# ('2015-08-01', '2015-08-31')
# ...current queue length 847
# ('2015-09-01', '2015-09-30')
# ...current queue length 848
# ('2015-10-01', '2015-10-31')
# ...current queue length 849
# ('2016-05-01', '2016-05-31')
# ...current queue length 850
# ('2016-06-01', '2016-06-30')
# ...current queue length 851
# ('2016-07-01', '2016-07-31')
# ...current queue length 852
# ('2016-08-01', '2016-08-31')
# ...current queue length 853
# ('2016-09-01', '2016-09-30')
# ...current queue length 854
# ('2016-10-01', '2016-10-31')
# ...current queue length 855
# ('2017-05-01', '2017-05-31')
# ...current queue length 856
# ('2017-06-01', '2017-06-30')
# ...current queue length 857
# ('2017-07-01', '2017-07-31')
# ...current queue length 858
# ('2017-08-01', '2017-08-31')
# ...current queue length 859
# ('2017-09-01', '2017-09-30')
# ...current queue length 860
# ('2017-10-01', '2017-10-31')
# ...current queue length 860
# ('2018-05-01', '2018-05-31')
# ...current queue length 861
# ('2018-06-01', '2018-06-30')
# ...current queue length 862
# ('2018-07-01', '2018-07-31')
# ...current queue length 863
# ('2018-08-01', '2018-08-31')
# ...current queue length 864
# ('2018-09-01', '2018-09-30')
# ...current queue length 865
# ('2018-10-01', '2018-10-31')
# ...current queue length 866
# ('2019-05-01', '2019-05-31')
# ...current queue length 867
# ('2019-06-01', '2019-06-30')
# ...current queue length 868
# ('2019-07-01', '2019-07-31')
# ...current queue length 869
# ('2019-08-01', '2019-08-31')
# ...current queue length 870
# ('2019-09-01', '2019-09-30')
# ...current queue length 871
# ('2019-10-01', '2019-10-31')
# ...current queue length 872
# ('2020-05-01', '2020-05-31')
# ...current queue length 873
# ('2020-06-01', '2020-06-30')
# ...current queue length 874
# ('2020-07-01', '2020-07-31')
# ...current queue length 875
# ('2020-08-01', '2020-08-31')
# ...current queue length 876
# ('2020-09-01', '2020-09-30')
# ...current queue length 877
# ('2020-10-01', '2020-10-31')
# ...current queue length 878
# ('2021-05-01', '2021-05-31')
# ...current queue length 879
# ('2021-06-01', '2021-06-30')
# ...current queue length 880
# ('2021-07-01', '2021-07-31')
# ...current queue length 881
# ('2021-08-01', '2021-08-31')
# ...current queue length 882
# ('2021-09-01', '2021-09-30')
# ...current queue length 883
# ('2021-10-01', '2021-10-31')
# ...current queue length 882
# ('2022-05-01', '2022-05-31')
# ...current queue length 883
# ('2022-06-01', '2022-06-30')
# ...current queue length 884
# ('2022-07-01', '2022-07-31')
# ...current queue length 885
# ('2022-08-01', '2022-08-31')
# ...current queue length 886
# ('2022-09-01', '2022-09-30')
# ...current queue length 887
# ('2022-10-01', '2022-10-31')
# ...current queue length 888
# ('2023-05-01', '2023-05-31')
# ...current queue length 889
# ('2023-06-01', '2023-06-30')
# ...current queue length 890
# ('2023-07-01', '2023-07-31')
# ...current queue length 891
# ('2023-08-01', '2023-08-31')
# ...current queue length 892
# ('2023-09-01', '2023-09-30')
# ...current queue length 893
# ('2023-10-01', '2023-10-31')
# ...current queue length 894
# ('2024-05-01', '2024-05-31')
# ...current queue length 895
# ('2024-06-01', '2024-06-30')
# ...current queue length 896
# ('2024-07-01', '2024-07-31')
# ...current queue length 897
# ('2024-08-01', '2024-08-31')
# ...current queue length 898
# ('2024-09-01', '2024-09-30')
# ...current queue length 899
# ('2024-10-01', '2024-10-31')
# ...current queue length 900
# ('2025-05-01', '2025-05-31')
# ...current queue length 901
# ('2025-06-01', '2025-06-30')
# ...current queue length 902
# ('2025-07-01', '2025-07-31')
# ...current queue length 903
# ('2025-08-01', '2025-08-15')
# ...current queue length 904
# ...moving on...
#
# Glacier # 56
# Glacier ID used for output file names: RGI2000-v7.0-G-01-15798
# Glacier area = 28.11403570383214 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15798_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 904
# ('2016-06-01', '2016-06-30')
# ...current queue length 905
# ('2016-07-01', '2016-07-31')
# ...current queue length 906
# ('2016-08-01', '2016-08-31')
# ...current queue length 907
# ('2016-09-01', '2016-09-30')
# ...current queue length 908
# ('2016-10-01', '2016-10-31')
# ...current queue length 909
# ('2017-05-01', '2017-05-31')
# ...current queue length 910
# ('2017-06-01', '2017-06-30')
# ...current queue length 911
# ('2017-07-01', '2017-07-31')
# ...current queue length 912
# ('2017-08-01', '2017-08-31')
# ...current queue length 913
# ('2017-09-01', '2017-09-30')
# ...current queue length 914
# ('2017-10-01', '2017-10-31')
# ...current queue length 915
# ('2018-05-01', '2018-05-31')
# ...current queue length 916
# ('2018-06-01', '2018-06-30')
# ...current queue length 917
# ('2018-07-01', '2018-07-31')
# ...current queue length 918
# ('2018-08-01', '2018-08-31')
# ...current queue length 919
# ('2018-09-01', '2018-09-30')
# ...current queue length 920
# ('2018-10-01', '2018-10-31')
# ...current queue length 921
# ('2019-05-01', '2019-05-31')
# ...current queue length 922
# ('2019-06-01', '2019-06-30')
# ...current queue length 923
# ('2019-07-01', '2019-07-31')
# ...current queue length 924
# ('2019-08-01', '2019-08-31')
# ...current queue length 925
# ('2019-09-01', '2019-09-30')
# ...current queue length 926
# ('2019-10-01', '2019-10-31')
# ...current queue length 927
# ('2020-05-01', '2020-05-31')
# ...current queue length 928
# ('2020-06-01', '2020-06-30')
# ...current queue length 929
# ('2020-07-01', '2020-07-31')
# ...current queue length 930
# ('2020-08-01', '2020-08-31')
# ...current queue length 931
# ('2020-09-01', '2020-09-30')
# ...current queue length 932
# ('2020-10-01', '2020-10-31')
# ...current queue length 933
# ('2021-05-01', '2021-05-31')
# ...current queue length 934
# ('2021-06-01', '2021-06-30')
# ...current queue length 935
# ('2021-07-01', '2021-07-31')
# ...current queue length 936
# ('2021-08-01', '2021-08-31')
# ...current queue length 937
# ('2021-09-01', '2021-09-30')
# ...current queue length 938
# ('2021-10-01', '2021-10-31')
# ...current queue length 939
# ('2022-05-01', '2022-05-31')
# ...current queue length 940
# ('2022-06-01', '2022-06-30')
# ...current queue length 941
# ('2022-07-01', '2022-07-31')
# ...current queue length 940
# ('2022-08-01', '2022-08-31')
# ...current queue length 941
# ('2022-09-01', '2022-09-30')
# ...current queue length 941
# ('2022-10-01', '2022-10-31')
# ...current queue length 942
# ('2023-05-01', '2023-05-31')
# ...current queue length 943
# ('2023-06-01', '2023-06-30')
# ...current queue length 944
# ('2023-07-01', '2023-07-31')
# ...current queue length 945
# ('2023-08-01', '2023-08-31')
# ...current queue length 946
# ('2023-09-01', '2023-09-30')
# ...current queue length 947
# ('2023-10-01', '2023-10-31')
# ...current queue length 948
# ('2024-05-01', '2024-05-31')
# ...current queue length 949
# ('2024-06-01', '2024-06-30')
# ...current queue length 950
# ('2024-07-01', '2024-07-31')
# ...current queue length 951
# ('2024-08-01', '2024-08-31')
# ...current queue length 952
# ('2024-09-01', '2024-09-30')
# ...current queue length 953
# ('2024-10-01', '2024-10-31')
# ...current queue length 954
# ('2025-05-01', '2025-05-31')
# ...current queue length 955
# ('2025-06-01', '2025-06-30')
# ...current queue length 956
# ('2025-07-01', '2025-07-31')
# ...current queue length 957
# ('2025-08-01', '2025-08-15')
# ...current queue length 958
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15798_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 959
# ('2019-06-01', '2019-06-30')
# ...current queue length 960
# ('2019-07-01', '2019-07-31')
# ...current queue length 961
# ('2019-08-01', '2019-08-31')
# ...current queue length 962
# ('2019-09-01', '2019-09-30')
# ...current queue length 963
# ('2019-10-01', '2019-10-31')
# ...current queue length 964
# ('2020-05-01', '2020-05-31')
# ...current queue length 965
# ('2020-06-01', '2020-06-30')
# ...current queue length 966
# ('2020-07-01', '2020-07-31')
# ...current queue length 967
# ('2020-08-01', '2020-08-31')
# ...current queue length 968
# ('2020-09-01', '2020-09-30')
# ...current queue length 969
# ('2020-10-01', '2020-10-31')
# ...current queue length 970
# ('2021-05-01', '2021-05-31')
# ...current queue length 971
# ('2021-06-01', '2021-06-30')
# ...current queue length 972
# ('2021-07-01', '2021-07-31')
# ...current queue length 973
# ('2021-08-01', '2021-08-31')
# ...current queue length 974
# ('2021-09-01', '2021-09-30')
# ...current queue length 975
# ('2021-10-01', '2021-10-31')
# ...current queue length 975
# ('2022-05-01', '2022-05-31')
# ...current queue length 976
# ('2022-06-01', '2022-06-30')
# ...current queue length 977
# ('2022-07-01', '2022-07-31')
# ...current queue length 978
# ('2022-08-01', '2022-08-31')
# ...current queue length 979
# ('2022-09-01', '2022-09-30')
# ...current queue length 979
# ('2022-10-01', '2022-10-31')
# ...current queue length 980
# ('2023-05-01', '2023-05-31')
# ...current queue length 981
# ('2023-06-01', '2023-06-30')
# ...current queue length 982
# ('2023-07-01', '2023-07-31')
# ...current queue length 983
# ('2023-08-01', '2023-08-31')
# ...current queue length 984
# ('2023-09-01', '2023-09-30')
# ...current queue length 985
# ('2023-10-01', '2023-10-31')
# ...current queue length 986
# ('2024-05-01', '2024-05-31')
# ...current queue length 987
# ('2024-06-01', '2024-06-30')
# ...current queue length 988
# ('2024-07-01', '2024-07-31')
# ...current queue length 989
# ('2024-08-01', '2024-08-31')
# ...current queue length 990
# ('2024-09-01', '2024-09-30')
# ...current queue length 991
# ('2024-10-01', '2024-10-31')
# ...current queue length 992
# ('2025-05-01', '2025-05-31')
# ...current queue length 993
# ('2025-06-01', '2025-06-30')
# ...current queue length 994
# ('2025-07-01', '2025-07-31')
# ...current queue length 995
# ('2025-08-01', '2025-08-15')
# ...current queue length 996
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-15798_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 997
# ('2014-06-01', '2014-06-30')
# ...current queue length 998
# ('2014-07-01', '2014-07-31')
# ...current queue length 999
# ('2014-08-01', '2014-08-31')
# ...current queue length 1000
# ('2014-09-01', '2014-09-30')
# ...current queue length 1001
# ('2014-10-01', '2014-10-31')
# ...current queue length 1002
# ('2015-05-01', '2015-05-31')
# ...current queue length 1003
# ('2015-06-01', '2015-06-30')
# ...current queue length 1004
# ('2015-07-01', '2015-07-31')
# ...current queue length 1005
# ('2015-08-01', '2015-08-31')
# ...current queue length 1006
# ('2015-09-01', '2015-09-30')
# ...current queue length 1007
# ('2015-10-01', '2015-10-31')
# ...current queue length 1008
# ('2016-05-01', '2016-05-31')
# ...current queue length 1009
# ('2016-06-01', '2016-06-30')
# ...current queue length 1010
# ('2016-07-01', '2016-07-31')
# ...current queue length 1011
# ('2016-08-01', '2016-08-31')
# ...current queue length 1012
# ('2016-09-01', '2016-09-30')
# ...current queue length 1013
# ('2016-10-01', '2016-10-31')
# ...current queue length 1014
# ('2017-05-01', '2017-05-31')
# ...current queue length 1015
# ('2017-06-01', '2017-06-30')
# ...current queue length 1016
# ('2017-07-01', '2017-07-31')
# ...current queue length 1017
# ('2017-08-01', '2017-08-31')
# ...current queue length 1018
# ('2017-09-01', '2017-09-30')
# ...current queue length 1019
# ('2017-10-01', '2017-10-31')
# ...current queue length 1020
# ('2018-05-01', '2018-05-31')
# ...current queue length 1021
# ('2018-06-01', '2018-06-30')
# ...current queue length 1022
# ('2018-07-01', '2018-07-31')
# ...current queue length 1023
# ('2018-08-01', '2018-08-31')
# ...current queue length 1024
# ('2018-09-01', '2018-09-30')
# ...current queue length 1025
# ('2018-10-01', '2018-10-31')
# ...current queue length 1026
# ('2019-05-01', '2019-05-31')
# ...current queue length 1027
# ('2019-06-01', '2019-06-30')
# ...current queue length 1028
# ('2019-07-01', '2019-07-31')
# ...current queue length 1029
# ('2019-08-01', '2019-08-31')
# ...current queue length 1030
# ('2019-09-01', '2019-09-30')
# ...current queue length 1031
# ('2019-10-01', '2019-10-31')
# ...current queue length 1032
# ('2020-05-01', '2020-05-31')
# ...current queue length 1033
# ('2020-06-01', '2020-06-30')
# ...current queue length 1034
# ('2020-07-01', '2020-07-31')
# ...current queue length 1035
# ('2020-08-01', '2020-08-31')
# ...current queue length 1036
# ('2020-09-01', '2020-09-30')
# ...current queue length 1037
# ('2020-10-01', '2020-10-31')
# ...current queue length 1038
# ('2021-05-01', '2021-05-31')
# ...current queue length 1039
# ('2021-06-01', '2021-06-30')
# ...current queue length 1040
# ('2021-07-01', '2021-07-31')
# ...current queue length 1041
# ('2021-08-01', '2021-08-31')
# ...current queue length 1042
# ('2021-09-01', '2021-09-30')
# ...current queue length 1043
# ('2021-10-01', '2021-10-31')
# ...current queue length 1044
# ('2022-05-01', '2022-05-31')
# ...current queue length 1045
# ('2022-06-01', '2022-06-30')
# ...current queue length 1046
# ('2022-07-01', '2022-07-31')
# ...current queue length 1047
# ('2022-08-01', '2022-08-31')
# ...current queue length 1047
# ('2022-09-01', '2022-09-30')
# ...current queue length 1047
# ('2022-10-01', '2022-10-31')
# ...current queue length 1048
# ('2023-05-01', '2023-05-31')
# ...current queue length 1049
# ('2023-06-01', '2023-06-30')
# ...current queue length 1050
# ('2023-07-01', '2023-07-31')
# ...current queue length 1051
# ('2023-08-01', '2023-08-31')
# ...current queue length 1052
# ('2023-09-01', '2023-09-30')
# ...current queue length 1053
# ('2023-10-01', '2023-10-31')
# ...current queue length 1054
# ('2024-05-01', '2024-05-31')
# ...current queue length 1055
# ('2024-06-01', '2024-06-30')
# ...current queue length 1056
# ('2024-07-01', '2024-07-31')
# ...current queue length 1057
# ('2024-08-01', '2024-08-31')
# ...current queue length 1058
# ('2024-09-01', '2024-09-30')
# ...current queue length 1059
# ('2024-10-01', '2024-10-31')
# ...current queue length 1060
# ('2025-05-01', '2025-05-31')
# ...current queue length 1061
# ('2025-06-01', '2025-06-30')
# ...current queue length 1062
# ('2025-07-01', '2025-07-31')
# ...current queue length 1063
# ('2025-08-01', '2025-08-15')
# ...current queue length 1064
# ...moving on...
#
# Glacier # 57
# Glacier ID used for output file names: RGI2000-v7.0-G-01-12441
# Glacier area = 92.57433311449414 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12441_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 1065
# ('2016-06-01', '2016-06-30')
# ...current queue length 1066
# ('2016-07-01', '2016-07-31')
# ...current queue length 1067
# ('2016-08-01', '2016-08-31')
# ...current queue length 1068
# ('2016-09-01', '2016-09-30')
# ...current queue length 1069
# ('2016-10-01', '2016-10-31')
# ...current queue length 1070
# ('2017-05-01', '2017-05-31')
# ...current queue length 1071
# ('2017-06-01', '2017-06-30')
# ...current queue length 1071
# ('2017-07-01', '2017-07-31')
# ...current queue length 1072
# ('2017-08-01', '2017-08-31')
# ...current queue length 1073
# ('2017-09-01', '2017-09-30')
# ...current queue length 1074
# ('2017-10-01', '2017-10-31')
# ...current queue length 1075
# ('2018-05-01', '2018-05-31')
# ...current queue length 1076
# ('2018-06-01', '2018-06-30')
# ...current queue length 1077
# ('2018-07-01', '2018-07-31')
# ...current queue length 1078
# ('2018-08-01', '2018-08-31')
# ...current queue length 1079
# ('2018-09-01', '2018-09-30')
# ...current queue length 1080
# ('2018-10-01', '2018-10-31')
# ...current queue length 1081
# ('2019-05-01', '2019-05-31')
# ...current queue length 1082
# ('2019-06-01', '2019-06-30')
# ...current queue length 1083
# ('2019-07-01', '2019-07-31')
# ...current queue length 1084
# ('2019-08-01', '2019-08-31')
# ...current queue length 1085
# ('2019-09-01', '2019-09-30')
# ...current queue length 1086
# ('2019-10-01', '2019-10-31')
# ...current queue length 1086
# ('2020-05-01', '2020-05-31')
# ...current queue length 1087
# ('2020-06-01', '2020-06-30')
# ...current queue length 1088
# ('2020-07-01', '2020-07-31')
# ...current queue length 1089
# ('2020-08-01', '2020-08-31')
# ...current queue length 1090
# ('2020-09-01', '2020-09-30')
# ...current queue length 1091
# ('2020-10-01', '2020-10-31')
# ...current queue length 1092
# ('2021-05-01', '2021-05-31')
# ...current queue length 1093
# ('2021-06-01', '2021-06-30')
# ...current queue length 1094
# ('2021-07-01', '2021-07-31')
# ...current queue length 1095
# ('2021-08-01', '2021-08-31')
# ...current queue length 1096
# ('2021-09-01', '2021-09-30')
# ...current queue length 1097
# ('2021-10-01', '2021-10-31')
# ...current queue length 1098
# ('2022-05-01', '2022-05-31')
# ...current queue length 1099
# ('2022-06-01', '2022-06-30')
# ...current queue length 1100
# ('2022-07-01', '2022-07-31')
# ...current queue length 1101
# ('2022-08-01', '2022-08-31')
# ...current queue length 1102
# ('2022-09-01', '2022-09-30')
# ...current queue length 1102
# ('2022-10-01', '2022-10-31')
# ...current queue length 1103
# ('2023-05-01', '2023-05-31')
# ...current queue length 1103
# ('2023-06-01', '2023-06-30')
# ...current queue length 1104
# ('2023-07-01', '2023-07-31')
# ...current queue length 1105
# ('2023-08-01', '2023-08-31')
# ...current queue length 1106
# ('2023-09-01', '2023-09-30')
# ...current queue length 1107
# ('2023-10-01', '2023-10-31')
# ...current queue length 1108
# ('2024-05-01', '2024-05-31')
# ...current queue length 1109
# ('2024-06-01', '2024-06-30')
# ...current queue length 1110
# ('2024-07-01', '2024-07-31')
# ...current queue length 1111
# ('2024-08-01', '2024-08-31')
# ...current queue length 1112
# ('2024-09-01', '2024-09-30')
# ...current queue length 1113
# ('2024-10-01', '2024-10-31')
# ...current queue length 1114
# ('2025-05-01', '2025-05-31')
# ...current queue length 1115
# ('2025-06-01', '2025-06-30')
# ...current queue length 1116
# ('2025-07-01', '2025-07-31')
# ...current queue length 1117
# ('2025-08-01', '2025-08-15')
# ...current queue length 1118
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12441_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 1119
# ('2019-06-01', '2019-06-30')
# ...current queue length 1120
# ('2019-07-01', '2019-07-31')
# ...current queue length 1121
# ('2019-08-01', '2019-08-31')
# ...current queue length 1121
# ('2019-09-01', '2019-09-30')
# ...current queue length 1122
# ('2019-10-01', '2019-10-31')
# ...current queue length 1123
# ('2020-05-01', '2020-05-31')
# ...current queue length 1124
# ('2020-06-01', '2020-06-30')
# ...current queue length 1125
# ('2020-07-01', '2020-07-31')
# ...current queue length 1126
# ('2020-08-01', '2020-08-31')
# ...current queue length 1127
# ('2020-09-01', '2020-09-30')
# ...current queue length 1128
# ('2020-10-01', '2020-10-31')
# ...current queue length 1129
# ('2021-05-01', '2021-05-31')
# ...current queue length 1130
# ('2021-06-01', '2021-06-30')
# ...current queue length 1131
# ('2021-07-01', '2021-07-31')
# ...current queue length 1132
# ('2021-08-01', '2021-08-31')
# ...current queue length 1133
# ('2021-09-01', '2021-09-30')
# ...current queue length 1134
# ('2021-10-01', '2021-10-31')
# ...current queue length 1135
# ('2022-05-01', '2022-05-31')
# ...current queue length 1136
# ('2022-06-01', '2022-06-30')
# ...current queue length 1137
# ('2022-07-01', '2022-07-31')
# ...current queue length 1138
# ('2022-08-01', '2022-08-31')
# ...current queue length 1139
# ('2022-09-01', '2022-09-30')
# ...current queue length 1140
# ('2022-10-01', '2022-10-31')
# ...current queue length 1141
# ('2023-05-01', '2023-05-31')
# ...current queue length 1141
# ('2023-06-01', '2023-06-30')
# ...current queue length 1142
# ('2023-07-01', '2023-07-31')
# ...current queue length 1143
# ('2023-08-01', '2023-08-31')
# ...current queue length 1144
# ('2023-09-01', '2023-09-30')
# ...current queue length 1145
# ('2023-10-01', '2023-10-31')
# ...current queue length 1146
# ('2024-05-01', '2024-05-31')
# ...current queue length 1147
# ('2024-06-01', '2024-06-30')
# ...current queue length 1148
# ('2024-07-01', '2024-07-31')
# ...current queue length 1149
# ('2024-08-01', '2024-08-31')
# ...current queue length 1150
# ('2024-09-01', '2024-09-30')
# ...current queue length 1151
# ('2024-10-01', '2024-10-31')
# ...current queue length 1152
# ('2025-05-01', '2025-05-31')
# ...current queue length 1153
# ('2025-06-01', '2025-06-30')
# ...current queue length 1154
# ('2025-07-01', '2025-07-31')
# ...current queue length 1155
# ('2025-08-01', '2025-08-15')
# ...current queue length 1156
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12441_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 1157
# ('2014-06-01', '2014-06-30')
# ...current queue length 1158
# ('2014-07-01', '2014-07-31')
# ...current queue length 1159
# ('2014-08-01', '2014-08-31')
# ...current queue length 1160
# ('2014-09-01', '2014-09-30')
# ...current queue length 1160
# ('2014-10-01', '2014-10-31')
# ...current queue length 1162
# ('2015-05-01', '2015-05-31')
# ...current queue length 1162
# ('2015-06-01', '2015-06-30')
# ...current queue length 1163
# ('2015-07-01', '2015-07-31')
# ...current queue length 1164
# ('2015-08-01', '2015-08-31')
# ...current queue length 1165
# ('2015-09-01', '2015-09-30')
# ...current queue length 1166
# ('2015-10-01', '2015-10-31')
# ...current queue length 1167
# ('2016-05-01', '2016-05-31')
# ...current queue length 1168
# ('2016-06-01', '2016-06-30')
# ...current queue length 1169
# ('2016-07-01', '2016-07-31')
# ...current queue length 1170
# ('2016-08-01', '2016-08-31')
# ...current queue length 1171
# ('2016-09-01', '2016-09-30')
# ...current queue length 1172
# ('2016-10-01', '2016-10-31')
# ...current queue length 1173
# ('2017-05-01', '2017-05-31')
# ...current queue length 1174
# ('2017-06-01', '2017-06-30')
# ...current queue length 1175
# ('2017-07-01', '2017-07-31')
# ...current queue length 1176
# ('2017-08-01', '2017-08-31')
# ...current queue length 1177
# ('2017-09-01', '2017-09-30')
# ...current queue length 1178
# ('2017-10-01', '2017-10-31')
# ...current queue length 1179
# ('2018-05-01', '2018-05-31')
# ...current queue length 1180
# ('2018-06-01', '2018-06-30')
# ...current queue length 1181
# ('2018-07-01', '2018-07-31')
# ...current queue length 1182
# ('2018-08-01', '2018-08-31')
# ...current queue length 1183
# ('2018-09-01', '2018-09-30')
# ...current queue length 1184
# ('2018-10-01', '2018-10-31')
# ...current queue length 1185
# ('2019-05-01', '2019-05-31')
# ...current queue length 1186
# ('2019-06-01', '2019-06-30')
# ...current queue length 1187
# ('2019-07-01', '2019-07-31')
# ...current queue length 1188
# ('2019-08-01', '2019-08-31')
# ...current queue length 1189
# ('2019-09-01', '2019-09-30')
# ...current queue length 1190
# ('2019-10-01', '2019-10-31')
# ...current queue length 1190
# ('2020-05-01', '2020-05-31')
# ...current queue length 1191
# ('2020-06-01', '2020-06-30')
# ...current queue length 1192
# ('2020-07-01', '2020-07-31')
# ...current queue length 1193
# ('2020-08-01', '2020-08-31')
# ...current queue length 1194
# ('2020-09-01', '2020-09-30')
# ...current queue length 1195
# ('2020-10-01', '2020-10-31')
# ...current queue length 1196
# ('2021-05-01', '2021-05-31')
# ...current queue length 1197
# ('2021-06-01', '2021-06-30')
# ...current queue length 1198
# ('2021-07-01', '2021-07-31')
# ...current queue length 1199
# ('2021-08-01', '2021-08-31')
# ...current queue length 1200
# ('2021-09-01', '2021-09-30')
# ...current queue length 1201
# ('2021-10-01', '2021-10-31')
# ...current queue length 1202
# ('2022-05-01', '2022-05-31')
# ...current queue length 1203
# ('2022-06-01', '2022-06-30')
# ...current queue length 1204
# ('2022-07-01', '2022-07-31')
# ...current queue length 1205
# ('2022-08-01', '2022-08-31')
# ...current queue length 1206
# ('2022-09-01', '2022-09-30')
# ...current queue length 1207
# ('2022-10-01', '2022-10-31')
# ...current queue length 1208
# ('2023-05-01', '2023-05-31')
# ...current queue length 1209
# ('2023-06-01', '2023-06-30')
# ...current queue length 1210
# ('2023-07-01', '2023-07-31')
# ...current queue length 1211
# ('2023-08-01', '2023-08-31')
# ...current queue length 1212
# ('2023-09-01', '2023-09-30')
# ...current queue length 1213
# ('2023-10-01', '2023-10-31')
# ...current queue length 1214
# ('2024-05-01', '2024-05-31')
# ...current queue length 1215
# ('2024-06-01', '2024-06-30')
# ...current queue length 1216
# ('2024-07-01', '2024-07-31')
# ...current queue length 1217
# ('2024-08-01', '2024-08-31')
# ...current queue length 1218
# ('2024-09-01', '2024-09-30')
# ...current queue length 1219
# ('2024-10-01', '2024-10-31')
# ...current queue length 1220
# ('2025-05-01', '2025-05-31')
# ...current queue length 1221
# ('2025-06-01', '2025-06-30')
# ...current queue length 1222
# ('2025-07-01', '2025-07-31')
# ...current queue length 1223
# ('2025-08-01', '2025-08-15')
# ...current queue length 1224
# ...moving on...
#
# Glacier # 58
# Glacier ID used for output file names: RGI2000-v7.0-G-01-12420
# Glacier area = 95.50011992370351 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12420_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 1225
# ('2016-06-01', '2016-06-30')
# ...current queue length 1226
# ('2016-07-01', '2016-07-31')
# ...current queue length 1227
# ('2016-08-01', '2016-08-31')
# ...current queue length 1228
# ('2016-09-01', '2016-09-30')
# ...current queue length 1229
# ('2016-10-01', '2016-10-31')
# ...current queue length 1230
# ('2017-05-01', '2017-05-31')
# ...current queue length 1231
# ('2017-06-01', '2017-06-30')
# ...current queue length 1231
# ('2017-07-01', '2017-07-31')
# ...current queue length 1232
# ('2017-08-01', '2017-08-31')
# ...current queue length 1233
# ('2017-09-01', '2017-09-30')
# ...current queue length 1233
# ('2017-10-01', '2017-10-31')
# ...current queue length 1234
# ('2018-05-01', '2018-05-31')
# ...current queue length 1235
# ('2018-06-01', '2018-06-30')
# ...current queue length 1236
# ('2018-07-01', '2018-07-31')
# ...current queue length 1237
# ('2018-08-01', '2018-08-31')
# ...current queue length 1238
# ('2018-09-01', '2018-09-30')
# ...current queue length 1239
# ('2018-10-01', '2018-10-31')
# ...current queue length 1240
# ('2019-05-01', '2019-05-31')
# ...current queue length 1241
# ('2019-06-01', '2019-06-30')
# ...current queue length 1242
# ('2019-07-01', '2019-07-31')
# ...current queue length 1243
# ('2019-08-01', '2019-08-31')
# ...current queue length 1244
# ('2019-09-01', '2019-09-30')
# ...current queue length 1245
# ('2019-10-01', '2019-10-31')
# ...current queue length 1246
# ('2020-05-01', '2020-05-31')
# ...current queue length 1247
# ('2020-06-01', '2020-06-30')
# ...current queue length 1248
# ('2020-07-01', '2020-07-31')
# ...current queue length 1249
# ('2020-08-01', '2020-08-31')
# ...current queue length 1250
# ('2020-09-01', '2020-09-30')
# ...current queue length 1251
# ('2020-10-01', '2020-10-31')
# ...current queue length 1252
# ('2021-05-01', '2021-05-31')
# ...current queue length 1253
# ('2021-06-01', '2021-06-30')
# ...current queue length 1254
# ('2021-07-01', '2021-07-31')
# ...current queue length 1255
# ('2021-08-01', '2021-08-31')
# ...current queue length 1256
# ('2021-09-01', '2021-09-30')
# ...current queue length 1257
# ('2021-10-01', '2021-10-31')
# ...current queue length 1258
# ('2022-05-01', '2022-05-31')
# ...current queue length 1259
# ('2022-06-01', '2022-06-30')
# ...current queue length 1260
# ('2022-07-01', '2022-07-31')
# ...current queue length 1261
# ('2022-08-01', '2022-08-31')
# ...current queue length 1262
# ('2022-09-01', '2022-09-30')
# ...current queue length 1263
# ('2022-10-01', '2022-10-31')
# ...current queue length 1264
# ('2023-05-01', '2023-05-31')
# ...current queue length 1265
# ('2023-06-01', '2023-06-30')
# ...current queue length 1266
# ('2023-07-01', '2023-07-31')
# ...current queue length 1267
# ('2023-08-01', '2023-08-31')
# ...current queue length 1268
# ('2023-09-01', '2023-09-30')
# ...current queue length 1269
# ('2023-10-01', '2023-10-31')
# ...current queue length 1270
# ('2024-05-01', '2024-05-31')
# ...current queue length 1270
# ('2024-06-01', '2024-06-30')
# ...current queue length 1271
# ('2024-07-01', '2024-07-31')
# ...current queue length 1272
# ('2024-08-01', '2024-08-31')
# ...current queue length 1273
# ('2024-09-01', '2024-09-30')
# ...current queue length 1274
# ('2024-10-01', '2024-10-31')
# ...current queue length 1275
# ('2025-05-01', '2025-05-31')
# ...current queue length 1276
# ('2025-06-01', '2025-06-30')
# ...current queue length 1277
# ('2025-07-01', '2025-07-31')
# ...current queue length 1278
# ('2025-08-01', '2025-08-15')
# ...current queue length 1279
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12420_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 1279
# ('2019-06-01', '2019-06-30')
# ...current queue length 1280
# ('2019-07-01', '2019-07-31')
# ...current queue length 1281
# ('2019-08-01', '2019-08-31')
# ...current queue length 1282
# ('2019-09-01', '2019-09-30')
# ...current queue length 1283
# ('2019-10-01', '2019-10-31')
# ...current queue length 1284
# ('2020-05-01', '2020-05-31')
# ...current queue length 1285
# ('2020-06-01', '2020-06-30')
# ...current queue length 1286
# ('2020-07-01', '2020-07-31')
# ...current queue length 1287
# ('2020-08-01', '2020-08-31')
# ...current queue length 1288
# ('2020-09-01', '2020-09-30')
# ...current queue length 1289
# ('2020-10-01', '2020-10-31')
# ...current queue length 1290
# ('2021-05-01', '2021-05-31')
# ...current queue length 1291
# ('2021-06-01', '2021-06-30')
# ...current queue length 1292
# ('2021-07-01', '2021-07-31')
# ...current queue length 1293
# ('2021-08-01', '2021-08-31')
# ...current queue length 1294
# ('2021-09-01', '2021-09-30')
# ...current queue length 1295
# ('2021-10-01', '2021-10-31')
# ...current queue length 1296
# ('2022-05-01', '2022-05-31')
# ...current queue length 1297
# ('2022-06-01', '2022-06-30')
# ...current queue length 1298
# ('2022-07-01', '2022-07-31')
# ...current queue length 1299
# ('2022-08-01', '2022-08-31')
# ...current queue length 1300
# ('2022-09-01', '2022-09-30')
# ...current queue length 1301
# ('2022-10-01', '2022-10-31')
# ...current queue length 1302
# ('2023-05-01', '2023-05-31')
# ...current queue length 1303
# ('2023-06-01', '2023-06-30')
# ...current queue length 1304
# ('2023-07-01', '2023-07-31')
# ...current queue length 1305
# ('2023-08-01', '2023-08-31')
# ...current queue length 1306
# ('2023-09-01', '2023-09-30')
# ...current queue length 1307
# ('2023-10-01', '2023-10-31')
# ...current queue length 1308
# ('2024-05-01', '2024-05-31')
# ...current queue length 1309
# ('2024-06-01', '2024-06-30')
# ...current queue length 1310
# ('2024-07-01', '2024-07-31')
# ...current queue length 1311
# ('2024-08-01', '2024-08-31')
# ...current queue length 1312
# ('2024-09-01', '2024-09-30')
# ...current queue length 1312
# ('2024-10-01', '2024-10-31')
# ...current queue length 1313
# ('2025-05-01', '2025-05-31')
# ...current queue length 1314
# ('2025-06-01', '2025-06-30')
# ...current queue length 1315
# ('2025-07-01', '2025-07-31')
# ...current queue length 1316
# ('2025-08-01', '2025-08-15')
# ...current queue length 1317
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12420_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 1318
# ('2014-06-01', '2014-06-30')
# ...current queue length 1319
# ('2014-07-01', '2014-07-31')
# ...current queue length 1320
# ('2014-08-01', '2014-08-31')
# ...current queue length 1321
# ('2014-09-01', '2014-09-30')
# ...current queue length 1322
# ('2014-10-01', '2014-10-31')
# ...current queue length 1323
# ('2015-05-01', '2015-05-31')
# ...current queue length 1324
# ('2015-06-01', '2015-06-30')
# ...current queue length 1325
# ('2015-07-01', '2015-07-31')
# ...current queue length 1326
# ('2015-08-01', '2015-08-31')
# ...current queue length 1327
# ('2015-09-01', '2015-09-30')
# ...current queue length 1327
# ('2015-10-01', '2015-10-31')
# ...current queue length 1327
# ('2016-05-01', '2016-05-31')
# ...current queue length 1328
# ('2016-06-01', '2016-06-30')
# ...current queue length 1329
# ('2016-07-01', '2016-07-31')
# ...current queue length 1330
# ('2016-08-01', '2016-08-31')
# ...current queue length 1331
# ('2016-09-01', '2016-09-30')
# ...current queue length 1332
# ('2016-10-01', '2016-10-31')
# ...current queue length 1333
# ('2017-05-01', '2017-05-31')
# ...current queue length 1334
# ('2017-06-01', '2017-06-30')
# ...current queue length 1335
# ('2017-07-01', '2017-07-31')
# ...current queue length 1336
# ('2017-08-01', '2017-08-31')
# ...current queue length 1337
# ('2017-09-01', '2017-09-30')
# ...current queue length 1338
# ('2017-10-01', '2017-10-31')
# ...current queue length 1339
# ('2018-05-01', '2018-05-31')
# ...current queue length 1340
# ('2018-06-01', '2018-06-30')
# ...current queue length 1341
# ('2018-07-01', '2018-07-31')
# ...current queue length 1342
# ('2018-08-01', '2018-08-31')
# ...current queue length 1343
# ('2018-09-01', '2018-09-30')
# ...current queue length 1344
# ('2018-10-01', '2018-10-31')
# ...current queue length 1345
# ('2019-05-01', '2019-05-31')
# ...current queue length 1346
# ('2019-06-01', '2019-06-30')
# ...current queue length 1347
# ('2019-07-01', '2019-07-31')
# ...current queue length 1348
# ('2019-08-01', '2019-08-31')
# ...current queue length 1349
# ('2019-09-01', '2019-09-30')
# ...current queue length 1350
# ('2019-10-01', '2019-10-31')
# ...current queue length 1351
# ('2020-05-01', '2020-05-31')
# ...current queue length 1352
# ('2020-06-01', '2020-06-30')
# ...current queue length 1353
# ('2020-07-01', '2020-07-31')
# ...current queue length 1354
# ('2020-08-01', '2020-08-31')
# ...current queue length 1355
# ('2020-09-01', '2020-09-30')
# ...current queue length 1356
# ('2020-10-01', '2020-10-31')
# ...current queue length 1357
# ('2021-05-01', '2021-05-31')
# ...current queue length 1358
# ('2021-06-01', '2021-06-30')
# ...current queue length 1359
# ('2021-07-01', '2021-07-31')
# ...current queue length 1360
# ('2021-08-01', '2021-08-31')
# ...current queue length 1361
# ('2021-09-01', '2021-09-30')
# ...current queue length 1362
# ('2021-10-01', '2021-10-31')
# ...current queue length 1363
# ('2022-05-01', '2022-05-31')
# ...current queue length 1364
# ('2022-06-01', '2022-06-30')
# ...current queue length 1365
# ('2022-07-01', '2022-07-31')
# ...current queue length 1365
# ('2022-08-01', '2022-08-31')
# ...current queue length 1366
# ('2022-09-01', '2022-09-30')
# ...current queue length 1367
# ('2022-10-01', '2022-10-31')
# ...current queue length 1368
# ('2023-05-01', '2023-05-31')
# ...current queue length 1369
# ('2023-06-01', '2023-06-30')
# ...current queue length 1370
# ('2023-07-01', '2023-07-31')
# ...current queue length 1371
# ('2023-08-01', '2023-08-31')
# ...current queue length 1372
# ('2023-09-01', '2023-09-30')
# ...current queue length 1373
# ('2023-10-01', '2023-10-31')
# ...current queue length 1374
# ('2024-05-01', '2024-05-31')
# ...current queue length 1375
# ('2024-06-01', '2024-06-30')
# ...current queue length 1376
# ('2024-07-01', '2024-07-31')
# ...current queue length 1377
# ('2024-08-01', '2024-08-31')
# ...current queue length 1378
# ('2024-09-01', '2024-09-30')
# ...current queue length 1378
# ('2024-10-01', '2024-10-31')
# ...current queue length 1379
# ('2025-05-01', '2025-05-31')
# ...current queue length 1380
# ('2025-06-01', '2025-06-30')
# ...current queue length 1381
# ('2025-07-01', '2025-07-31')
# ...current queue length 1382
# ('2025-08-01', '2025-08-15')
# ...current queue length 1383
# ...moving on...
#
# Glacier # 59
# Glacier ID used for output file names: RGI2000-v7.0-G-01-16691
# Glacier area = 14.618141307703501 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 99 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-16691_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 1384
# ('2016-06-01', '2016-06-30')
# ...current queue length 1385
# ('2016-07-01', '2016-07-31')
# ...current queue length 1386
# ('2016-08-01', '2016-08-31')
# ...current queue length 1387
# ('2016-09-01', '2016-09-30')
# ...current queue length 1388
# ('2016-10-01', '2016-10-31')
# ...current queue length 1389
# ('2017-05-01', '2017-05-31')
# ...current queue length 1390
# ('2017-06-01', '2017-06-30')
# ...current queue length 1391
# ('2017-07-01', '2017-07-31')
# ...current queue length 1392
# ('2017-08-01', '2017-08-31')
# ...current queue length 1393
# ('2017-09-01', '2017-09-30')
# ...current queue length 1394
# ('2017-10-01', '2017-10-31')
# ...current queue length 1395
# ('2018-05-01', '2018-05-31')
# ...current queue length 1396
# ('2018-06-01', '2018-06-30')
# ...current queue length 1397
# ('2018-07-01', '2018-07-31')
# ...current queue length 1398
# ('2018-08-01', '2018-08-31')
# ...current queue length 1399
# ('2018-09-01', '2018-09-30')
# ...current queue length 1400
# ('2018-10-01', '2018-10-31')
# ...current queue length 1401
# ('2019-05-01', '2019-05-31')
# ...current queue length 1402
# ('2019-06-01', '2019-06-30')
# ...current queue length 1403
# ('2019-07-01', '2019-07-31')
# ...current queue length 1404
# ('2019-08-01', '2019-08-31')
# ...current queue length 1404
# ('2019-09-01', '2019-09-30')
# ...current queue length 1405
# ('2019-10-01', '2019-10-31')
# ...current queue length 1406
# ('2020-05-01', '2020-05-31')
# ...current queue length 1407
# ('2020-06-01', '2020-06-30')
# ...current queue length 1408
# ('2020-07-01', '2020-07-31')
# ...current queue length 1409
# ('2020-08-01', '2020-08-31')
# ...current queue length 1410
# ('2020-09-01', '2020-09-30')
# ...current queue length 1411
# ('2020-10-01', '2020-10-31')
# ...current queue length 1412
# ('2021-05-01', '2021-05-31')
# ...current queue length 1413
# ('2021-06-01', '2021-06-30')
# ...current queue length 1414
# ('2021-07-01', '2021-07-31')
# ...current queue length 1415
# ('2021-08-01', '2021-08-31')
# ...current queue length 1416
# ('2021-09-01', '2021-09-30')
# ...current queue length 1417
# ('2021-10-01', '2021-10-31')
# ...current queue length 1417
# ('2022-05-01', '2022-05-31')
# ...current queue length 1418
# ('2022-06-01', '2022-06-30')
# ...current queue length 1419
# ('2022-07-01', '2022-07-31')
# ...current queue length 1420
# ('2022-08-01', '2022-08-31')
# ...current queue length 1421
# ('2022-09-01', '2022-09-30')
# ...current queue length 1422
# ('2022-10-01', '2022-10-31')
# ...current queue length 1423
# ('2023-05-01', '2023-05-31')
# ...current queue length 1424
# ('2023-06-01', '2023-06-30')
# ...current queue length 1425
# ...
# sleep time = 240 s
# ('2020-09-01', '2020-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2020-10-01', '2020-10-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2021-05-01', '2021-05-31')
# ...current queue length 2997
# ('2021-06-01', '2021-06-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2021-07-01', '2021-07-31')
# ...current queue length 2995
# ('2021-08-01', '2021-08-31')
# ...current queue length 2996
# ('2021-09-01', '2021-09-30')
# ...current queue length 2997
# ('2021-10-01', '2021-10-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2022-05-01', '2022-05-31')
# ...current queue length 2994
# ('2022-06-01', '2022-06-30')
# ...current queue length 2995
# ('2022-07-01', '2022-07-31')
# ...current queue length 2996
# ('2022-08-01', '2022-08-31')
# ...current queue length 2997
# ('2022-09-01', '2022-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2022-10-01', '2022-10-31')
# ...current queue length 2994
# ('2023-05-01', '2023-05-31')
# ...current queue length 2995
# ('2023-06-01', '2023-06-30')
# ...current queue length 2996
# ('2023-07-01', '2023-07-31')
# ...current queue length 2997
# ('2023-08-01', '2023-08-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2023-09-01', '2023-09-30')
# ...current queue length 2997
# ('2023-10-01', '2023-10-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2024-05-01', '2024-05-31')
# ...current queue length 2994
# ('2024-06-01', '2024-06-30')
# ...current queue length 2995
# ('2024-07-01', '2024-07-31')
# ...current queue length 2995
# ('2024-08-01', '2024-08-31')
# ...current queue length 2996
# ('2024-09-01', '2024-09-30')
# ...current queue length 2997
# ('2024-10-01', '2024-10-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2025-05-01', '2025-05-31')
# ...current queue length 2996
# ('2025-06-01', '2025-06-30')
# ...current queue length 2997
# ('2025-07-01', '2025-07-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2025-08-01', '2025-08-15')
# ...current queue length 2996
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12416_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 2997
# ('2019-06-01', '2019-06-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2019-07-01', '2019-07-31')
# ...current queue length 2996
# ('2019-08-01', '2019-08-31')
# ...current queue length 2995
# ('2019-09-01', '2019-09-30')
# ...current queue length 2996
# ('2019-10-01', '2019-10-31')
# ...current queue length 2997
# ('2020-05-01', '2020-05-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2020-06-01', '2020-06-30')
# ...current queue length 2995
# ('2020-07-01', '2020-07-31')
# ...current queue length 2996
# ('2020-08-01', '2020-08-31')
# ...current queue length 2997
# ('2020-09-01', '2020-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2020-10-01', '2020-10-31')
# ...current queue length 2995
# ('2021-05-01', '2021-05-31')
# ...current queue length 2996
# ('2021-06-01', '2021-06-30')
# ...current queue length 2997
# ('2021-07-01', '2021-07-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2021-08-01', '2021-08-31')
# ...current queue length 2991
# ('2021-09-01', '2021-09-30')
# ...current queue length 2991
# ('2021-10-01', '2021-10-31')
# ...current queue length 2991
# ('2022-05-01', '2022-05-31')
# ...current queue length 2992
# ('2022-06-01', '2022-06-30')
# ...current queue length 2993
# ('2022-07-01', '2022-07-31')
# ...current queue length 2994
# ('2022-08-01', '2022-08-31')
# ...current queue length 2994
# ('2022-09-01', '2022-09-30')
# ...current queue length 2994
# ('2022-10-01', '2022-10-31')
# ...current queue length 2995
# ('2023-05-01', '2023-05-31')
# ...current queue length 2996
# ('2023-06-01', '2023-06-30')
# ...current queue length 2996
# ('2023-07-01', '2023-07-31')
# ...current queue length 2997
# ('2023-08-01', '2023-08-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2023-09-01', '2023-09-30')
# ...current queue length 2990
# ('2023-10-01', '2023-10-31')
# ...current queue length 2991
# ('2024-05-01', '2024-05-31')
# ...current queue length 2991
# ('2024-06-01', '2024-06-30')
# ...current queue length 2992
# ('2024-07-01', '2024-07-31')
# ...current queue length 2993
# ('2024-08-01', '2024-08-31')
# ...current queue length 2994
# ('2024-09-01', '2024-09-30')
# ...current queue length 2994
# ('2024-10-01', '2024-10-31')
# ...current queue length 2995
# ('2025-05-01', '2025-05-31')
# ...current queue length 2996
# ('2025-06-01', '2025-06-30')
# ...current queue length 2997
# ('2025-07-01', '2025-07-31')
# ...current queue length 2996
# ('2025-08-01', '2025-08-15')
# ...current queue length 2997
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 70
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12416_Landsat_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2014-05-01', '2014-05-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2014-06-01', '2014-06-30')
# ...current queue length 2988
# ('2014-07-01', '2014-07-31')
# ...current queue length 2989
# ('2014-08-01', '2014-08-31')
# ...current queue length 2990
# ('2014-09-01', '2014-09-30')
# ...current queue length 2990
# ('2014-10-01', '2014-10-31')
# ...current queue length 2991
# ('2015-05-01', '2015-05-31')
# ...current queue length 2991
# ('2015-06-01', '2015-06-30')
# ...current queue length 2992
# ('2015-07-01', '2015-07-31')
# ...current queue length 2993
# ('2015-08-01', '2015-08-31')
# ...current queue length 2994
# ('2015-09-01', '2015-09-30')
# ...current queue length 2995
# ('2015-10-01', '2015-10-31')
# ...current queue length 2995
# ('2016-05-01', '2016-05-31')
# ...current queue length 2996
# ('2016-06-01', '2016-06-30')
# ...current queue length 2995
# ('2016-07-01', '2016-07-31')
# ...current queue length 2996
# ('2016-08-01', '2016-08-31')
# ...current queue length 2997
# ('2016-09-01', '2016-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2016-10-01', '2016-10-31')
# ...current queue length 2994
# ('2017-05-01', '2017-05-31')
# ...current queue length 2995
# ('2017-06-01', '2017-06-30')
# ...current queue length 2996
# ('2017-07-01', '2017-07-31')
# ...current queue length 2997
# ('2017-08-01', '2017-08-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2017-09-01', '2017-09-30')
# ...current queue length 2997
# ('2017-10-01', '2017-10-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2018-05-01', '2018-05-31')
# ...current queue length 2996
# ('2018-06-01', '2018-06-30')
# ...current queue length 2997
# ('2018-07-01', '2018-07-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2018-08-01', '2018-08-31')
# ...current queue length 2991
# ('2018-09-01', '2018-09-30')
# ...current queue length 2992
# ('2018-10-01', '2018-10-31')
# ...current queue length 2993
# ('2019-05-01', '2019-05-31')
# ...current queue length 2994
# ('2019-06-01', '2019-06-30')
# ...current queue length 2994
# ('2019-07-01', '2019-07-31')
# ...current queue length 2995
# ('2019-08-01', '2019-08-31')
# ...current queue length 2996
# ('2019-09-01', '2019-09-30')
# ...current queue length 2997
# ('2019-10-01', '2019-10-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2020-05-01', '2020-05-31')
# ...current queue length 2995
# ('2020-06-01', '2020-06-30')
# ...current queue length 2996
# ('2020-07-01', '2020-07-31')
# ...current queue length 2997
# ('2020-08-01', '2020-08-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2020-09-01', '2020-09-30')
# ...current queue length 2995
# ('2020-10-01', '2020-10-31')
# ...current queue length 2996
# ('2021-05-01', '2021-05-31')
# ...current queue length 2997
# ('2021-06-01', '2021-06-30')
# ...current queue length 2997
# ('2021-07-01', '2021-07-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2021-08-01', '2021-08-31')
# ...current queue length 2997
# ('2021-09-01', '2021-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2021-10-01', '2021-10-31')
# ...current queue length 2996
# ('2022-05-01', '2022-05-31')
# ...current queue length 2997
# ('2022-06-01', '2022-06-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2022-07-01', '2022-07-31')
# ...current queue length 2996
# ('2022-08-01', '2022-08-31')
# ...current queue length 2997
# ('2022-09-01', '2022-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2022-10-01', '2022-10-31')
# ...current queue length 2997
# ('2023-05-01', '2023-05-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2023-06-01', '2023-06-30')
# ...current queue length 2997
# ('2023-07-01', '2023-07-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2023-08-01', '2023-08-31')
# ...current queue length 2996
# ('2023-09-01', '2023-09-30')
# ...current queue length 2997
# ('2023-10-01', '2023-10-31')
# ...current queue length 2998
# sleep time = 240 s
# sleep time = 240 s
# ('2024-05-01', '2024-05-31')
# ...current queue length 2997
# ('2024-06-01', '2024-06-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2024-07-01', '2024-07-31')
# ...current queue length 2997
# ('2024-08-01', '2024-08-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2024-09-01', '2024-09-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2024-10-01', '2024-10-31')
# ...current queue length 2997
# ('2025-05-01', '2025-05-31')
# ...current queue length 2998
# sleep time = 240 s
# ('2025-06-01', '2025-06-30')
# ...current queue length 2998
# sleep time = 240 s
# ('2025-07-01', '2025-07-31')
# ...current queue length 2996
# ('2025-08-01', '2025-08-15')
# ...current queue length 2997
# ...moving on...
#
# Glacier # 83
# Glacier ID used for output file names: RGI2000-v7.0-G-01-12741
# Glacier area = 15.24844922444624 km2
#
# Querying GEE for DEM
# ArcticDEM coverage = 100 %
# Using ArcticDEM Mosaic
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 58
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12741_Sentinel-2_TOA_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2016-05-01', '2016-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2016-06-01', '2016-06-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2016-07-01', '2016-07-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2016-08-01', '2016-08-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2016-09-01', '2016-09-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2016-10-01', '2016-10-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2017-05-01', '2017-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2017-06-01', '2017-06-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2017-07-01', '2017-07-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2017-08-01', '2017-08-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2017-09-01', '2017-09-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2017-10-01', '2017-10-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2018-05-01', '2018-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2018-06-01', '2018-06-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2018-07-01', '2018-07-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2018-08-01', '2018-08-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2018-09-01', '2018-09-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2018-10-01', '2018-10-31')
# ...current queue length 2997
# ('2019-05-01', '2019-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2019-06-01', '2019-06-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2019-07-01', '2019-07-31')
# ...current queue length 2997
# ('2019-08-01', '2019-08-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2019-09-01', '2019-09-30')
# ...current queue length 2997
# ('2019-10-01', '2019-10-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2020-05-01', '2020-05-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2020-06-01', '2020-06-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2020-07-01', '2020-07-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2020-08-01', '2020-08-31')
# ...current queue length 2997
# ('2020-09-01', '2020-09-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2020-10-01', '2020-10-31')
# ...current queue length 2997
# ('2021-05-01', '2021-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2021-06-01', '2021-06-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2021-07-01', '2021-07-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2021-08-01', '2021-08-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2021-09-01', '2021-09-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2021-10-01', '2021-10-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2022-05-01', '2022-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2022-06-01', '2022-06-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2022-07-01', '2022-07-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2022-08-01', '2022-08-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2022-09-01', '2022-09-30')
# ...current queue length 2997
# ('2022-10-01', '2022-10-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2023-05-01', '2023-05-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2023-06-01', '2023-06-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2023-07-01', '2023-07-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2023-08-01', '2023-08-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2023-09-01', '2023-09-30')
# ...current queue length 2997
# ('2023-10-01', '2023-10-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2024-05-01', '2024-05-31')
# ...current queue length 2997
# ('2024-06-01', '2024-06-30')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2024-07-01', '2024-07-31')
# ...current queue length 2998
# sleep time = 90 s
# ('2024-08-01', '2024-08-31')
# ...current queue length 2996
# ('2024-09-01', '2024-09-30')
# ...current queue length 2997
# ('2024-10-01', '2024-10-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2025-05-01', '2025-05-31')
# ...current queue length 2996
# ('2025-06-01', '2025-06-30')
# ...current queue length 2997
# ('2025-07-01', '2025-07-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# sleep time = 90 s
# ('2025-08-01', '2025-08-15')
# ...current queue length 2997
# AOI area < 500 km2 — splitting date range by month.
# Number of date ranges = 40
# Exporting snow cover statistics to glacier-snow-cover_exports Google Drive folder with file naming convention: RGI2000-v7.0-G-01-12741_Sentinel-2_SR_snow_cover_stats_DATE-START_DATE-END.csv
# To monitor export tasks, see your Google Cloud Console or GEE Task Manager: https://code.earthengine.google.com/tasks
# ('2019-05-01', '2019-05-31')
# ...current queue length 2998
# sleep time = 90 s
# sleep time = 90 s
# ('2019-06-01', '2019-06-30')
# ...current queue length 2998
# sleep time = 90 s
# ('2019-07-01', '2019-07-31')
# ...current queue length 2999
# sleep time = 90 s
# sleep time = 90 s
